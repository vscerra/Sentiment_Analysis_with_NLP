# %% [markdown]
# # Sentiment Analysis of Movie Review Data with Logistic Regression and Naive Bayes Algorithms

# %% [markdown]
# ## Objective

# %% [markdown]
# The goal of this project is to perform a sentiment analysis of text data from movie reviews using two different classification algorithms - Logistic Regression and Naive Bayes - and compare their performance.

# %% [markdown]
# ## Data Collection and Preparation

# %% [markdown]
# This dataset was organized and labeled by Bo Pang and Lillian Li, and used in their paper "Seeing Stars: Exploiting class relationships for sentiment categorization with respect to rating scales" (2005) from Proceedings of the ACL. It contains 5331 positive and 5331 negative review snippets culled from the Rotten Tomatoes movie review website. Positive reviews were those designated as "fresh" and negative reviews were those designated "rotten" on the website. The full data set can be accessed [here](http://www.cs.cornell.edu/people/pabo/movie-review-data)

# %% [markdown]
# ### Import and split the data into train, validation, and test sets

# %%
# initialize empty lists to store positive and negative reviews
positive_reviews = []
negative_reviews = []

# read the positive and negative reviews into their respective lists from the data files
with open("rt-polaritydata/rt-polaritydata/positive_reviews.txt", "r") as positive_file:
    for line in positive_file:
        # remove leading/trailing whitespaces and add to positive_reviews
        positive_reviews.append(line.strip())

with open("rt-polaritydata/rt-polaritydata/rt-polarity.neg", "r") as negative_file:
    for line in negative_file:
        # remove leading/trailing whitespaces and add to positive_reviews
        negative_reviews.append(line.strip())
        
# print the first few lines from each list as a sample
print("Sample Positive Reviews: ")
print(positive_reviews[:3])
print("Sample Negative Reviews: ")
print(negative_reviews[:3])
# Out:
# Sample Positive Reviews:
# ['the rock is destined to be the 21st century\'s new " conan " and that he\'s going to make a splash even greater than arnold schwarzenegger , jean-claud van damme or steven segal .', 'the gorgeously elaborate continuation of " the lord of the rings " trilogy is so huge that a column of words cannot adequately describe co-writer/director peter jackson\'s expanded vision of j . r . r . tolkien\'s middle-earth .', 'effective but too-tepid biopic']
# Sample Negative Reviews:
# ['simplistic , silly and tedious .', "it's so laddish and juvenile , only teenage boys could possibly find it funny .", 'exploitative and largely devoid of the depth or sophistication that would make watching such a graphic treatment of the crimes bearable .']

# %%
# create the x-variable
x = positive_reviews + negative_reviews
print(len(x))
# create the y-variable
y = [1] * len(positive_reviews) + [0] * len(negative_reviews)
print(len(y))
# Out:
# 10662
# 10662

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size = 0.3, random_state = 0)
x_valid, x_test, y_valid, y_test = train_test_split(x_temp, y_temp, test_size = 0.5, random_state = 0)
print("length of x_train = " + str(len(x_train)))
print("length of y_train = " + str(len(y_train)))
print("length of x_valid = " + str(len(x_valid)))
print("length of y_valid = " + str(len(y_valid)))
print("length of x_test = " + str(len(x_test)))
print("length of y_test = " + str(len(y_test)))

y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)
# Out:
# length of x_train = 7463
# length of y_train = 7463
# length of x_valid = 1599
# length of y_valid = 1599
# length of x_test = 1600
# length of y_test = 1600

# %% [markdown]
# ### Import necessary functions for text processing

# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
import re                                   # library for regular expression operations
import string                               # for string operations
from nltk.corpus import stopwords           # module for stop words that comes with NLTK
from nltk.stem import PorterStemmer         # module for stemming
from nltk.tokenize import word_tokenize    # module for tokenizing

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vscerra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vscerra\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Create a function to preprocess the data using the nltk library to remove unnecessary punctuation and hyperlinks, tokenize, stem words, and remove stopwords

# %%
def process_text(text):
    ''' 
    Input: 
        text: a string of words or characters 
    Output:
        processed_text: original text with hyperlinks and punctuation removed, made lowercase, and with words tokenized and stemmed    
    
    '''
    # remove hyperlinks using regex
    text = re.sub(r'https\S+','', text)
    
    # remove punctuation and convert to lowercase
    text = re.sub(r'[^\w\s]','', text).lower()
    
    # tokenize the text
    words = word_tokenize(text)
    
    # remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    
    # stem the words
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in filtered_words]
    
    processed_text = stemmed_words
    return processed_text

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# ### Build a frequency dictionary

# %% [markdown]
# Both the logistic regression and the Naive Bayes algorithm make use of frequency dictionary, `freqs`, built below. Each word and sentiment pair is counted from the labeled texts, so we can know how many times each word appears in positive and negative reviews.

# %%
# initialize the defaultdict to store word-sentiment frequency counts
freqs = {}

# iterate through the reviews and labels in the training set
for review, label in zip(x_train, y_train):
    words = process_text(review)
    
    for word in words:
        pair = (word, label)
        if pair in freqs:
            freqs[pair] +=1
        else:
            freqs[pair] = 1

# %%
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 16805

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output. This conversion lets us use our regression as a classifier - returning values above or below a threshold, rather than a continuous output.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$

# %% [markdown]
# #### Sigmoid
# The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} $$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.

# %%
# Sigmoid function
def sigmoid(z):
    '''
    Input: 
        z: input, can be scalar or array
    Output: 
        h: the sigmoid of z
    '''
    import numpy as np
    import math
    h = 1 / (1 + np.exp(-z))
    
    return h

# %% [markdown]
# #### Cost function and gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of training example 'i'.
# * $h(z^{(i)})$ is the model's prediction for the training example 'i'.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.

# %% [markdown]
# #### Update the weights
#
# To update the weight vector $\theta$, we will apply gradient descent to iteratively improve the model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x^{(i)}_j $$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x^{(i)}_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# #### Gradient descent
#
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %%
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector

    '''
   
    m = np.shape(x)[0]

    for i in range(0, num_iters):
    
        # get z, the dot product of x and theta
        z = np.dot(x,theta)
        
        # get the sigmoid of z
        h = sigmoid(z)
        
        # calculate the cost function
        J = (-1/m) * (np.dot(np.transpose(y), np.log(h)) + np.dot(np.transpose(1-y), np.log(1-h)))

        # update the weights theta
        theta = theta - (alpha / m) * np.dot(np.transpose(x), (h-y))
        
    J = float(J)
    return J, theta

# %% [markdown]
# #### Extract features from the test set
#
# In order to apply logistic regression to the review text, we need to go through our corpus and for each review, create a three-element vector representing:
#
# + a bias term = 1
#
# + the cumulative count of all occurrences of the positive words from each review in the corpus
#
# + the cumulative count of all occurrences of the negative words from each review in the corpus.
#
# So for each review, we will have a vector that looks like this:

# %% [markdown]
# <center>
# x = [1, positive count, negative count]
# </center>
#
# By cycling through the corpus of reviews and stacking the above vectors, we can build the feature matrix for the logistic regression model.

# %%
def extract_features(review, freqs, process_text = process_text):
    '''
    Input: 
        review: list of words for one review
        freqs: a dictionary correspoding to the frequencies of each (word, label) tuple
    Output: 
        x: a feature vector of dimensions (1,3) (bias, positive, negative)
    '''
    # process the review
    word_l = process_text(review)
    
    # preallocate the 3-element counts
    x = np.zeros(3)
    
    # set the bias term to 1
    x[0] = 1
    
    # loop through each word on the list
    for word in word_l: 
        pair_p = (word, 1)
        if pair_p in freqs: 
            # increment the word count for the positive label
            x[1] += freqs[pair_p]
        pair_n = (word, 0)
        if pair_n in freqs: 
            x[2] += freqs[pair_n]
            
    x = x[None, :] # adding batch dimension
    assert(x.shape == (1,3))
    return x

# %% [markdown]
# #### Predict review sentiment
#
# Using the extracted features of each review and the sigmoid function, we can get a prediction of the review sentiment. In this case, a prediction between 0 and 0.5 (0 < y<sub>pred</sub> <= 0.5) is coded as a negative review, and a prediction between 0.5 and 1 (0.5 < y<sub>pred</sub> < 1) is coded as a positive review.

# %%
def predict_review_LR(review, freqs, theta): 
    '''
    Input: 
        review: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''

    # extract the features of the review and store it into x
    x = extract_features(review, freqs)

    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x, theta))
    
    return y_pred

# %% [markdown]
# #### Train the logistic regression model
#
# Training the model is simple once you have the above functions. All that remains is to extract all feature vectors from the processed text, then use the review labels and gradient descent to find the weights ($\theta$) that correspond with the lowest cost (${J}$).

# %%
def train_LR_model(x_train, y_train, alpha, num_iters, extract_features = extract_features, gradientDescent = gradientDescent):
    '''
    Input: 
        x_train: a list of reviews
        y_train: (m,1) vector arrow with the corresponding labels for the list of reviews
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output: 
        J: the final cost
        theta: your final weight vector
    '''
    # collect the features of "x" and stack them into a matrix "X"
    X = np.zeros((len(x_train), 3))
    for i in range(len(x_train)):
        X[i,:] = extract_features(x_train[i], freqs)


    # training labels that correspond to X
    Y = y_train.reshape(-1,1)

    # apply gradient descent
    J, theta = gradientDescent(X, Y, np.zeros((3,1)), alpha, num_iters)
    return J, theta

# %% [markdown]
# ### Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# To implement a Naive Bayes model, you need to create a probability that your document falls into one of your classes (in this case, positive and negative, or 2 classes).
#
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}$$
#
# Where $D$ is the total number of documents, or reviews in this case, $D_{pos}$ is the total number of positive reviews and $D_{neg}$ is the total number of negative reviews.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a review is positive versus negative.  In other words, if we had no specific information and blindly picked a review out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Since $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all reviews respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V} $$
#
# Note that in the above formulas, I include a +1 in the numerator; this is called Laplacian smoothing (or additive smoothing). It is a technique used to address the issue of zero probabilities for certain features, and improves the model's robustness. With Laplacian smoothing, even features that are not found in the training data can have a greater than zero probability in the model, ensuring that the Naive Bayes classifier can make predictions for features not seen during training.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)$$
#
#
# The above formulas and calculations are included in the `train_naive_bayes` function below, returning the logprior of the corpus and the loglikelihood dictionary of the words and labeled sentiments in the training set.

# %%
def train_naive_bayes(freqs, x_train, y_train): 
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        x_train: a list of reviews
        y_train: a list of labels correponding to the reviews (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    
    loglikelihood = {}
    logprior = 0
    
    # calculate V, the number of unique words in the vocabulary
    vocab = set(d[0] for d in freqs)
    V = len(vocab)
    
    # calculate N_pos, N_neg, V_pos, V_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        # if the label is positive
        if pair[1] > 0: 
            # increment the number of positive words by the count for this (word,label) pair
            N_pos += freqs.get(pair, 0)
        else:
            N_neg += freqs.get(pair, 0)
    
    # calculate D, the number of documents/reviews in the set
    D = len(y_train)
    
    # calculate D_pos, the number of positive reviews
    Y = y_train
    D_pos = np.count_nonzero(Y == 1)
    print("D_pos:", D_pos)
    # calculate D_neg, the number of negative reviews
    D_neg = D - D_pos
    print("D_neg:", D_neg)
    # calculate the logprior
    logprior = np.log(D_pos) - np.log(D_neg)
    
    # for each word in the vocabulary
    for word in vocab:
        # get positive and negative frequency of each word
        freq_pos = freqs.get((word, 1), 0)
        freq_neg = freqs.get((word, 0), 0)
        
        # calculate the probability that each word is positive and negative, using Laplacian smoothing
        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)
        
        # calculate the loglikelihood of the word
        loglikelihood[word] = np.log(p_w_pos / p_w_neg)
    
    return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, x_train, y_train)
print("logprior: ", logprior)
print("loglikelihood length", len(loglikelihood))
# Out:
# D_pos: 3762
# D_neg: 3701
# logprior:  0.0163476774748208
# loglikelihood length 12240

# %%
def predict_review_NB(review, logprior, loglikelihood):
    '''
    Input:
        review: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the review (if found in the dictionary) + logprior (a number)

    '''
    # process the review to get a list of words
    word_l = process_text(review)
    
    # initialize probability to zero
    p = 0
    
    # add the logprior
    p += logprior
    
    for word in word_l:
        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the loglikelihood of that word to the probability
            p+= loglikelihood.get(word)
    
    return(p)

# %% [markdown]
# ## Model Testing

# %% [markdown]
# ### Test the logistic regression model
#
# With the trained logistic regression model, you can then input your test set (or validation set) to evaluate the model's performance with new reviews.
#
# The `test_LR_model` function returns two measures of model performance:
# + **accuracy**: accuracy is simply the sum of correct predictions from the test set / size of test set
# + **F1 score**: F1 score is a common evaluation metric in binary classification that combines the use of both precision and recall performance measures
#     + Precision (P): precision is the ratio of correct positive predictions to all positive predictions (including true and false positives). What precision represents is the relevance of positive predicted incidences. P = TP / TP + FP
#     + Recall (R): recall is the ratio of correct positive predictions to all true positive cases (including true positives and false negatives. Recall represents the model's ability to correctly identify positive cases. R = TP / TP + FN
#     + F1 is the harmonic mean of P and R and is useful when you need a single metric to evaluate the performance of a binary classifier, particularly when data sets are unbalanced.
#     $$F1 = \frac{2 * (P * R)}{P + R}$$
#
#     + F1 scores range between 0 and 1, with 1 representing perfect precision and recall. A higher F1 score indicates a better precision/recall balance in the model

# %%
def test_LR_model(x, y, freqs, theta, predict_review_LR = predict_review_LR):
    '''
    Input: 
        test_x: a list of reviews
        test_y: (m, 1) vector array with the corresponding labels for the list of reviews
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
        f1: 2*(precision * recall) / (precision + recall) 
    '''

    # preallocate the list for storing predictions
    y_hat = []

    for review in x: 
        # get the predicted label
        y_pred = predict_review_LR(review, freqs, theta)
    
        if y_pred > 0.5:
            y_hat.append(1.0)
    
        else: 
            y_hat.append(0.0)
        

    accuracy = sum(y.flatten() == np.asarray(y_hat))/len(y)
    
    from sklearn.metrics import f1_score
    f1 = f1_score(y, y_hat)
    
    return accuracy, f1

# %% [markdown]
# #### Tune the learning rate hyperparameter ($\mathbf\alpha$)
#
# Now that we have the ability to train and test the model, we want to use the validation set to find the best learning rate for our gradient descent. Learning rate is a hyperparameter that dictates how large of a step to take down the gradient in the gradient descent algorithm. Selecting too large of a value for &alpha; can result in too large steps that miss the minimum of the cost function and lead to a failure to converge. Conversely, if you set the learning rate too small, convergence might be extremely slow and take the algorithm too long to find the minimum. Selecting the appropriate learning rate for your model improves your model's efficiency, performance, generalizability, and robustness, so it is important to test various values for &alpha; to find what works best.
#
# Below, I use a regular grid search to select the &alpha; parameter that returns the best accuracy with the model trained on the training set, and tested on the validation set. Then I use the model trained on the training set, with hyperparameter &alpha; tuned with the validation set, to test accuracy and F1 score with the test set.

# %%
# designate some learning rates to chose from
learning_rates = [3e-5, 1e-5, 6e-6, 3e-6, 1e-6, 6e-7, 3e-7, 1e-7, 6e-8, 3e-8, 1e-8, 6e-9, 3e-9, 1e-9]
best_learning_rate = None
best_accuracy = 0
num_iters = 2000

for lr in learning_rates: 
    # fit the model with the training set
    
    J_temp, theta_temp = train_LR_model(x_train, y_train, lr, num_iters, extract_features = extract_features, gradientDescent = gradientDescent)
    accuracy, f1 = test_LR_model(x_valid, y_valid, freqs, theta_temp, predict_review_LR = predict_review_LR)
    print(f"Learning Rate: {lr}, Validation Accuracy: {accuracy}")
    
    # update the best learning rate if needed
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_learning_rate = lr
    
print(f"Best Learning Rate determined with validation set: {best_learning_rate}")

# Train the model on the training set with the best learning rate
J, theta = train_LR_model(x_train, y_train, best_learning_rate, num_iters, extract_features = extract_features, gradientDescent = gradientDescent)
# Out:
# Learning Rate: 3e-05, Validation Accuracy: 0.6529080675422139
# Learning Rate: 1e-05, Validation Accuracy: 0.6791744840525328
# Learning Rate: 6e-06, Validation Accuracy: 0.6791744840525328
# Learning Rate: 3e-06, Validation Accuracy: 0.6791744840525328
# Learning Rate: 1e-06, Validation Accuracy: 0.6804252657911195
# Learning Rate: 6e-07, Validation Accuracy: 0.6804252657911195
# Learning Rate: 3e-07, Validation Accuracy: 0.6797998749218261
# Learning Rate: 1e-07, Validation Accuracy: 0.6754221388367729
# Learning Rate: 6e-08, Validation Accuracy: 0.6722951844903065
# Learning Rate: 3e-08, Validation Accuracy: 0.6666666666666666
# Learning Rate: 1e-08, Validation Accuracy: 0.6404002501563477
# Learning Rate: 6e-09, Validation Accuracy: 0.6260162601626016
# Learning Rate: 3e-09, Validation Accuracy: 0.6047529706066291
# Learning Rate: 1e-09, Validation Accuracy: 0.5616010006253909
# Best Learning Rate determined with validation set: 1e-06

# %% [markdown]
# ### Test Naive Bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predictions on the test set.
#
# In the logistic regression model, we were classifying outcomes as greater or less than 0.5. With the probabilities returned by the Naive Bayes model, a review with a p > 0 is classified as positive, while a review with p < 0 is classified as negative. Just as with the logistic regression model above, the test function for Naive Bayes returns accuracy and F1 score.
#
# ##### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (3727 positive and 3726 negative reviews).  This means that the ratio of positive to negative 1, and the logprior is (nearly) 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, the logprior is important because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
def test_naive_bayes(x_test, y_test, logprior, loglikelihood, predict_review_NB = predict_review_NB):
    '''
    Input:
        test_x: A list of reviews
        test_y: the corresponding labels for the list of reviews
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of reviews classified correctly)/(total # of reviews)
        f1: 2*(precision * recall) / (precision + recall) 
    '''
    accuracy = 0
    
    y_hats = []
    for review in x_test: 
        # if prediction is > 0
        if predict_review_NB(review, logprior, loglikelihood) > 0:
            # the predicted class is 1
            y_hat_i = 1
        else: 
            y_hat_i = 0
            
        # append the predicted class to the list of y_hats
        y_hats.append(y_hat_i)
        
    # error is the average of the absolute values of the differences between y_hats and test_y
    Y = y_test
    error = sum(abs(y_hats - Y))/len(Y)
    accuracy = 1 - error
    
    from sklearn.metrics import f1_score
    f1 = f1_score(Y, y_hats)
    
    return accuracy, f1

# %% [markdown]
# ### Evaluating model performance on the test set

# %%
# Evaluate the final model on the test set
test_accuracy_LR, f1_score_LR = test_LR_model(x_test, y_test, freqs, theta, predict_review_LR = predict_review_LR)
print(f"Test accuracy of LR model with best learning rate: {test_accuracy_LR:.3f}, and F1 score: {f1_score_LR:.3f}")
        

# Evaluate the final model on the test set
accuracy_NB, f1_NB = test_naive_bayes(x_test, y_test, logprior, loglikelihood)
print(f"Test accuracy of NB model with Laplacian smoothing: {accuracy_NB:.3f}, and F1 score: {f1_NB:.3f}")
# Out:
# Test accuracy of LR model with best learning rate: 0.673, and F1 score: 0.672
# Test accuracy of NB model with Laplacian smoothing: 0.760, and F1 score: 0.758

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# While the Naive Bayes model clearly outperformed the Logistic Regression model, both left many reviews misclassified. Let's look at the misclassified reviews to see if there's anything obviously driving the misclassification.

# %%
misclassified_LR = []
print('Truth Predicted Review')
for x, y in zip(x_test, y_test):
    y_hat = predict_review_LR(x, freqs, theta)
    if y_hat > 0.5:
        pred = 1.0
    else:
        pred = 0.0
    if y != pred:
        print('%d\t%0.2f\t%s' % (y, pred, ' '.join(process_text(x)).encode('ascii', 'ignore')))
        misclassified_LR.append(process_text(x))
# Out:
# Truth Predicted Review
# 0	1.00	b'director chri columbu take hatinhand approach rowl stifl creativ allow film drag nearli three hour'
# 0	1.00	b'effort sincer result honest film bleak hardli watchabl'
# 0	1.00	b'niftiest trick perpetr import earnest alchem transmogrif wild austenand hollywood austen'
# 0	1.00	b'motion pictur portray ultim passion other creat ultim thrill men black ii achiev ultim insignific scifi comedi spectacl whifflebal epic'
# 0	1.00	b'blanket statement dimestor rumin vaniti worri rich sudden wisdom film becom sermon run time'
# 1	0.00	b'walk away new version e hope would moist eye'
# 0	1.00	b'bravo reveal true intent film care select interview subject construct portrait castro predominantli charit seen propaganda'
# 0	1.00	b'cheer enough immin forgett ripoff besson earlier work'
# 0	1.00	b'incess loung music play film background may mistak love liza adam sandler chanukah song'
# 0	1.00	b'though film wellintent one could rent origin get love stori parabl'
# 1	0.00	b'go movi littl like chew whale blubber acquir tast take time enjoy worth even take 3 hour get'
# 1	0.00	b'movi stori much schmidt matter view selfreflect cautionari tale'
# 0	1.00	b'what offens isnt wast good cast film denial sincer grief mourn favor bogu spiritu'
# 1	0.00	b'birthday girl doesnt tri surpris us plot twist rather seem enjoy transpar'
# 0	1.00	b'support charact eastwood film weak subplot one weaker'
# 0	1.00	b'much film loopi ludicr could hoot badmovi way labori pace endless exposit tighten'
# 0	1.00	b'group selfabsorb women mother daughter featur film dont think noth wrong perform whiney charact bug'
# 0	1.00	b'predict bland comfort food appeal film pleasant enough dish'
# 1	0.00	b'may histori make one pure enjoy satisfi even movi ive'
# 0	1.00	b'leav us wonder less idea character hitler contriv natur provoc conclus'
# 0	1.00	b'gener slashermovi nonsens without style'
# 0	1.00	b'savetheplanet messag clash crass market'
# 1	0.00	b'there deni burn filmmak bright futur ahead'
# 0	1.00	b'pleasant recycl jock piffl'
# 0	1.00	b'enigmat film that clever good conundrum worth solv'
# 0	1.00	b'best film remain shortest hole make mani point film feel less repetit'
# 0	1.00	b'american adobo heart palat right place brain littl scatter ditsi even'
# 1	0.00	b'de niro murphi make showtim savori hilari guilti pleasur mani recent movi season'
# 1	0.00	b'confound solemnli advanc daringli preposter thesi act act'
# 0	1.00	b'martin scorses cria um espetculo visual que no possui alma um film esteticament belo ma emocionalment frio'
# 1	0.00	b'high crime steal freeli movi combin enough dispar type film cant help engag audienc'
# 0	1.00	b'tough astring darkli funni well also gener untidi condescend mild impact rather stun'
# 0	1.00	b'enigma look great solid act neat premis yet fail riddl wrap mysteri insid enigma'
# 0	1.00	b'russel lack visual panach comic touch perhap budget sommerss titlebout featur'
# 1	0.00	b'invent absorb movi that hard classifi hard resist'
# 0	1.00	b'captur conceptu process doesnt add suffici explan final danc work select becam final form'
# 0	1.00	b'perfectli enjoy instantli forgett noth write home'
# 1	0.00	b'uniqu stubborn charismat want better success'
# 0	1.00	b'affleck mere creat outlin role still need grow role ford effortlessli fill author'
# 1	0.00	b'one funnier movi town'
# 0	1.00	b'spider outrun motorcycl wrap person sticki cocoon second fall short interest entertain'
# 1	0.00	b'storytel valu deni even solondz thirst controversi sketchi charact immatur provoc fulli succeed cheapen'
# 0	1.00	b'puppi dog desper attent nearli break littl neck tri perform entertain trick'
# 1	0.00	b'movi best doesnt make charact flaw insist virtu imperfect'
# 1	0.00	b'fine movi go see'
# 1	0.00	b'gorgeou witti seduct movi'
# 0	1.00	b'director capabl cast appear caught headi whirl new ageinspir good intent spell cast isnt least bit mesmer'
# 1	0.00	b'digit effect remind terri gilliam rudimentari old monti python cartoon would cut figur draw photograph past togeth'
# 0	1.00	b'film lack person permeat aspect tv movieesqu affect child act dullest irish pub scene ever film'
# 1	0.00	b'one intellig children movi hit theater year'
# 0	1.00	b'joke work fail miser end pumpkin far offens funni'
# 1	0.00	b'year hollywood craft solid formula success anim movi ice age improv terrif comput graphic invent action sequenc droll sens humor'
# 0	1.00	b'rare much money deliv littl entertain'
# 1	0.00	b'farcic element seem pat familiar hold interest yet divert grim messag good one'
# 0	1.00	b'fail make charact understand get skin explor motiv well end film grow dull charact whose fate hard care'
# 0	1.00	b'despit juliet stevenon attempt bring cohes pamela emot roller coaster life enough give film substanc desper need'
# 1	0.00	b'human resourc good straightforward tale time better haunt like poem'
# 0	1.00	b'danc completist'
# 1	0.00	b'although doesnt alway hang togeth violenc whimsi dont combin easili cherish certainli isnt dull'
# 0	1.00	b'eastwood icon moviemak one best actor director produc around respons excel work even hero stumbl sometim'
# 1	0.00	b'13 convers hold goodwil close rel slow come point'
# 0	1.00	b'even ultim disappoint pictur matine admiss worth funni keep afloat'
# 0	1.00	b'wrap classic motherdaught struggl recycl paper shini new bow audienc tell new least look pretti'
# 0	1.00	b'campi work straight drama violent sordid function comedi vulgar truli thank oneofakind work'
# 1	0.00	b'gangster movi capac surpris'
# 0	1.00	b'best describ know last winter'
# 0	1.00	b'take clunki tvmovi approach detail chapter life celebr irish playwright poet drinker'
# 1	0.00	b'chanc see three splendid actor turn larki chase movi emot satisfi explor human need somebodi belong somebodi'
# 0	1.00	b'trivial profound hyperclich sincer'
# 0	1.00	b'succe provid disquiet world longdread complet polic academi seri'
# 1	0.00	b'movi ingeni fun see'
# 1	0.00	b'definit improv first blade sinc doesnt take deadli serious'
# 0	1.00	b'strident ineleg messagemovi postur'
# 0	1.00	b'though ganesh success midlevel sort way there noth strike fascin metaphor signific career rate two hour attent'
# 0	1.00	b'humor isnt sharp effect innov stori imagin origin could wors'
# 0	1.00	b'us respond strongli storytel computergener effect new star war instal hasnt escap rut dug last one'
# 1	0.00	b'conceptu brilliant play like livingroom war world gain unsettl forc suggest unknown'
# 1	0.00	b'holm embodi charact effortlessli regal charisma'
# 0	1.00	b'bewar quirki britcom turn dime oddli humor tedious sentiment'
# 0	1.00	b'unless zone ordin protect commun dullest scienc fiction impostor open today theater near'
# 0	1.00	b'might best enjoy daytim soaper'
# 1	0.00	b'ok arthous power script perform come whole damn thing didnt get moral hackl'
# 0	1.00	b'gener famili comedi unlik appreci anyon outsid under10 set'
# 0	1.00	b'your consciou effort take spontan'
# 0	1.00	b'kung pow oedekerk realiz childhood dream martialart flick prove sometim dream youth remain'
# 1	0.00	b'wont argu anyon call slacker dumb insult childish laugh much didnt mind'
# 0	1.00	b'skip film buy philip glass soundtrack cd'
# 1	0.00	b'nicol kidman evolv star superstar time past year mean birthday girl kind quirkili appeal minor movi might make'
# 1	0.00	b'baran shockingli devoid typic majid majidi shoelov crippl children'
# 0	1.00	b'brisk wang pace none excel cast given air breath'
# 1	0.00	b'awesom creatur breathtak sceneri epic battl scene add anoth spectacular spectacl'
# 0	1.00	b'normal rohmer talki film fascin move set past reli histor text lose rich character make film memor'
# 0	1.00	b'afterschool special without courag convict'
# 0	1.00	b'though avari done best make someth elli noth novel end rule bare worth follow'
# 1	0.00	b'sli femal empower movi although way anyon would expect'
# 0	1.00	b'despit gulp film fuzzi huggi'
# 1	0.00	b'escap studio piccoli warmli affect adroitli minimalist movi'
# 0	1.00	b'rice pedestrian filmmak bring edg person rise place would set apart deep south stori'
# 1	0.00	b'whole cast look much fun slapstick antic silli street patoi toss around obscur express like bellini mullinski compact 86 minut breez'
# 0	1.00	b'piano teacher sort movi discourag american audienc ever want see anoth foreign film'
# 0	1.00	b'unlik disturb disgust without redeem valu whatsoev'
# 0	1.00	b'watch film nearli provok take life hour win best pictur might'
# 1	0.00	b'like bizarr heroin irrig soul'
# 1	0.00	b'smart movi know classic music know freud know sade'
# 1	0.00	b'movi audienc hour doesnt connect neat way introduc charact illumin mysteri sex duti love'
# 1	0.00	b'whether like rap music loath cant deni either tragic loss two young men prime talent power movi'
# 0	1.00	b'what realli sad see two academi award win actress one academi award win actor succumb appear junk that tv sitcom materi best'
# 1	0.00	b'estrogen opera intens feminin serv antidot cannier doppelgang diesel xxx flexathon'
# 0	1.00	b'wellshot badli written tale set futur ravag dragon'
# 1	0.00	b'without brace truth that refresh phoni femalebond pictur like divin secret yaya sisterhood'
# 1	0.00	b'climact event well realiz may forget origin conflict like movi'
# 1	0.00	b'even naipaul origin remain real masterpiec movi possess languor charm'
# 1	0.00	b'enjoy frothi date movi'
# 0	1.00	b'viewer ask often suspend belief holm perform film would total washout'
# 1	0.00	b'campanella compet direct excel cast overcom obstacl predict outcom screenplay gloss rafael evolut'
# 0	1.00	b'scriptwrit less menac societi film charact'
# 0	1.00	b'film featur young children threaten terrorist bomb longer pass mere entertain'
# 1	0.00	b'gambl throw basketbal game money isnt new plot fact toback use black white toback derang immediaci make seem fresh'
# 1	0.00	b'miracul movi im go home slight yet overflow wisdom emot'
# 0	1.00	b'noth film possibl except elizabeth hurley breast authent'
# 0	1.00	b'lax limp comedi ive seen meander wornout materi'
# 0	1.00	b'instead use georg luci obviou differ ignit spark lawrenc desper look elsewher seiz georg hapless luci person tic'
# 0	1.00	b'go far enough humor stock idea stand particularli memor even funni'
# 0	1.00	b'lessthancompel documentari yiddish theater clan'
# 0	1.00	b'christ allegori doesnt work foundat'
# 0	1.00	b'process comedi chop suey'
# 0	1.00	b'mindless yet impress lean spinoff last summer bloat effect fest mummi return'
# 0	1.00	b'film tri patienc even cinemabesot critic one'
# 1	0.00	b'creepi authent dark disturb biopic hard forget'
# 0	1.00	b'sorvino make princess seem smug cartoonish film realli come aliv poor hermocr leontin pathet compar note bud amour'
# 0	1.00	b'jonah soso addit biblic messag either improv film lessen'
# 0	1.00	b'funniest american comedi sinc graffiti bridg'
# 0	1.00	b'pathet exploit film tri seem sincer seem wors effort'
# 0	1.00	b'mire shabbi script pile layer upon layer action man clich atop wooden dialogu shift tone fall far short peculiarli moral amor woo best work'
# 0	1.00	b'horrid littl propaganda film fascin connect serb also network american rightw extremist'
# 1	0.00	b'may captiv mood subtli transform star still wonder paul thoma anderson ever inclin make sincer art movi adam sandler probabl ever appear'
# 0	1.00	b'look like high school film project complet day due'
# 0	1.00	b'present good case fail provid reason us care beyond basic dictum human decenc'
# 1	0.00	b'fast funni highli enjoy movi'
# 1	0.00	b'safe conduct long movi 163 minut fill time drama romanc tragedi braveri polit intrigu partisan sabotag viva le resist'
# 1	0.00	b'without de niro citi sea would slip wave drag back singlehand'
# 0	1.00	b'believ make real deal leftov enron stock doubl valu week friday'
# 1	0.00	b'delight minor pastri movi'
# 1	0.00	b'scorses bold imag gener smart cast ensur gang never letharg movi hinder central plot that pepper fals start popul charact nearli imposs care'
# 1	0.00	b'fill alexandr desplat haunt sublim music movi complet transfix audienc'
# 1	0.00	b'pure propaganda work unabash hero worship nonetheless like inadvert time invalu implicit remind role u foreign polici play rise castro'
# 0	1.00	b'admit semiamus watch robert deniro belt your jet your jet way equal distast watch sing lyric tonight'
# 0	1.00	b'charm overli complic'
# 1	0.00	b'dont expect surpris checklist teamwork clich'
# 1	0.00	b'moonlight mile give freedom feel contradictori thing sentiment feel free offend analyt surrend illog charact grief yet permit laughter'
# 1	0.00	b'wonder hope magic never escap heart boy right movi come along especi begin name star war'
# 1	0.00	b'movi lot danc fabul music slow repetit part enough spice keep interest'
# 0	1.00	b'unclassifi aw studi self audienceabus'
# 1	0.00	b'even though mani guy less ador lament pretti much selfcent there someth vital movi'
# 1	0.00	b'long dishonor histori quicki teenpop exploit like mike stand partli synthet decenc'
# 0	1.00	b'singularli offput romant comedi'
# 1	0.00	b'una pelcula oscura precisa por momento grandiosa casi siempr conmovedora'
# 1	0.00	b'like big chill reunion baadermeinhof gang guy harmless prankster polit activist'
# 1	0.00	b'odditi sure one might wind rememb degre affect rather revuls'
# 0	1.00	b'script judgment sens weight way way'
# 0	1.00	b'wellmad mushheart'
# 0	1.00	b'bartlett hero remain reactiv cipher open man head heart imagin reason film made'
# 0	1.00	b'despit strong perform never rise level telanovela'
# 0	1.00	b'skill mr shyamalan undon pretens'
# 1	0.00	b'realli happen question philosoph filmmak filmmak need engag audienc'
# 0	1.00	b'juli davi kathi lee gifford film director sadli prove ego doesnt alway go hand hand talent'
# 0	1.00	b'definit crowdpleas roman colosseum'
# 0	1.00	b'sticki sweet sentiment clumsi plot rosili myopic view life wwiiera mississippi delta undermin adapt'
# 0	1.00	b'film center hold'
# 0	1.00	b'trashi exploit thoroughli unpleas experi'
# 1	0.00	b'instead hit audienc head moral schrader reli subtl ironi visual devic convey point view'
# 1	0.00	b'adapt kevin moloni simon ley novel death napoleon direct alan taylor napoleon journey interest parisian rebirth stillborn'
# 0	1.00	b'preposter tediou sonni spike unintent laughter unfortun occur infrequ make film even guilti pleasur'
# 1	0.00	b'trap wont score point polit correct may caus parent sleepless hour sign effect'
# 1	0.00	b'thought movi movi concern soul risk scheme consequ one action'
# 1	0.00	b'one rare doc paint grand pictur era make journey feel like parti'
# 0	1.00	b'cut hollywood satir instead fresh last week issu varieti'
# 0	1.00	b'time stand still way one clockstopp scifi thriller lazi intermin'
# 0	1.00	b'isnt nearli enough fun despit presenc appeal ingredi'
# 1	0.00	b'muccino direct screenplay canni crowd pleaser last kiss provid enough sentiment catharsi satisfi even multiplex'
# 0	1.00	b'fragil framework upon hang broad mildli fleshedout charact seem conjur 10 minut prior film'
# 1	0.00	b'sometim need comfort fantasi mental ill also need movi like tim mccann revolut 9'
# 0	1.00	b'influenc chiefli human greatest shame realiti show realiti show god sake crime punish chainsaw'
# 0	1.00	b'would prefer transfer hall mr holland class music robin williamss lectur could listen teacher humor passion verv'
# 0	1.00	b'sterl film cross boy dont cri deliver ode billi joe lie somewher stori matthew shepard film yet made'
# 1	0.00	b'excel unlik mani hollywood movi ilk offer hope'
# 1	0.00	b'much see horribl also undeni exceedingli clever'
# 0	1.00	b'downbeat nearli humorless becom chore sit despit firstrat perform lead'
# 0	1.00	b'selfstyl athlet bang brain ground frequent furious capac explain gone way natur instinct selfpreserv'
# 0	1.00	b'sympathi empathi piti fog screen secret life enter land unintent melodrama tiresom love triangl'
# 0	1.00	b'doesnt deliv great stori action grip past seagal film'
# 0	1.00	b'well expect'
# 1	0.00	b'triumph love silli movi silli pedigre'
# 0	1.00	b'stori actual quit vapid'
# 0	1.00	b'there persist theatric sentiment woozi qualiti manner storytel undercut devastatingli tell impact utter loss personifi film simpl titl'
# 0	1.00	b'unfortun neither sendak director particularli engag articul'
# 0	1.00	b'director cut add 51 minut take great film turn mundan soap opera'
# 0	1.00	b'though pretend expos life male hustler exploit without insight'
# 0	1.00	b'behan memoir great materi film rowdi brawni lyric best irish sens sheridan settl lugubri romanc'
# 0	1.00	b'sweet harmless dumb occasion funni compel fish show'
# 0	1.00	b'film taken liter level focu alway appear question'
# 0	1.00	b'seem film art rip peopl without ever let conscious know done'
# 1	0.00	b'shamelessli resort peerel sight gag might even caus tom green grimac still myer energi silli eventu prevail'
# 0	1.00	b'problem part film deadli dull'
# 1	0.00	b'gentl affect melodrama luvvi raptur far slight introspect appeal anyth wider nich audienc'
# 1	0.00	b'much better documentari reveal emot surpris pedestrian english titl would believ'
# 0	1.00	b'lessthanthril thriller'
# 1	0.00	b'begin end scene terrifi im still stun ive decid leav light everi night'
# 1	0.00	b'one entertain monster movi age'
# 0	1.00	b'turn potenti interest idea excruci film school experi play better film publicist peopl take mani drug film charact'
# 1	0.00	b'taut psycholog thriller doesnt wast moment twohour run time'
# 0	1.00	b'made discern craft monstrous sanctimoni deal childhood loss'
# 1	0.00	b'ali graduat littl screen big far less pain open scene encount overamor terrier'
# 0	1.00	b'credit must given harland william michael rosenbaum barri watson inject far goodnatur spirit talent project deserv'
# 0	1.00	b'unfortun wallac wrote gibson braveheart well recent pearl harbor irrepress passion sappi situat dialogu'
# 1	0.00	b'concept idea thrill ride fascin look futur bladerunn one highconcept sci fi adventur attempt screen'
# 0	1.00	b'drain life attempt sober educ yet devoid realism lack whistl bell make obnoxi stiff'
# 1	0.00	b'clint eastwood blood work lot like wellmad pb j sandwich familiar fairli unev boast real surpris still quit tasti invit'
# 1	0.00	b'hit everi clich weve come expect includ assumpt crazi peopl innoc childlik inher funni'
# 1	0.00	b'strength documentari disregard avail bia especi temptingli easi would premis'
# 1	0.00	b'intim goodhumor ethnic comedi like numer other cut deeper expect'
# 1	0.00	b'make movi comedi way avoid seriou emot involv'
# 1	0.00	b'movi soft percol magic deadpan suspens'
# 0	1.00	b'film aussi david caesar channel notquitedead career guy ritchi'
# 0	1.00	b'hardman grate manner onscreen presenc especi unfortun light fine work done rest cast'
# 0	1.00	b'fill lowbrow humor gratuit violenc disturb disregard life'
# 0	1.00	b'endur love exhaust cinema'
# 0	1.00	b'first mistak suspect cast shatner legendari professor kuni brilliant colleg studentwher pauli shore rocket scientist'
# 0	1.00	b'ultim film never recov clumsi clich ugli american abroad toofrosti exterior ms paltrow employ authent british persona anoth liabil'
# 0	1.00	b'think american pie valium'
# 1	0.00	b'nearli surreal dabbl french simpl movi youll take risk choos see enjoy ride bump creami depth ultim theme'
# 1	0.00	b'play profound crazier michael jackson top floor skyscrap nurseri surround open window'
# 0	1.00	b'holm terrif men hjejl quit appeal film fail make intrigu premis'
# 1	0.00	b'one slyli exquisit antiadult movi ever made'
# 0	1.00	b'creak rusti ship make fine backdrop ghost haunt routin'
# 0	1.00	b'nation lampoon van wilder may aim next anim hous close resembl year version tomcat'
# 0	1.00	b'chocol factori without charli'
# 1	0.00	b'thing guy like evan your never quit sure selfpromot end truth begin watch movi your interest care'
# 1	0.00	b'awkward sincer ultim win'
# 0	1.00	b'occasion interest mostli repetit look slice countercultur might best forgotten'
# 1	0.00	b'reno take credit movi success he one cool actor never seem awar cool'
# 1	0.00	b'wild thornberri movi jolli surpris'
# 0	1.00	b'filmmak know pleas eye alway prettiest pictur tell best stori'
# 0	1.00	b'stori friendship proce way your watch soap opera rather chronicl up down accompani lifelong friendship'
# 0	1.00	b'flaccid drama exasperatingli slow journey'
# 0	1.00	b'fun psycholog mess austin power bump head way closet'
# 0	1.00	b'meticul mount exasperatingli wellbehav film tick kahlo lifetim mileston duti precis tax account'
# 1	0.00	b'count time'
# 1	0.00	b'apart anyth els one bestsustain idea ever seen screen'
# 0	1.00	b'putrid worth price match use burn everi print film'
# 0	1.00	b'work lack purpos strong puls'
# 0	1.00	b'film take materi human tragedi dress love costum southern california locat star power'
# 0	1.00	b'one set sens humor nerv speak'
# 0	1.00	b'addict film violenc form find anyth appreci'
# 1	0.00	b'partyhearti teen flick scald like acid'
# 0	1.00	b'weep futur good portion respect critic commun countri consid blue crush intellig film young women'
# 0	1.00	b'passabl romant comedi need anoth coupl pass word processor'
# 1	0.00	b'would unendur view experi ultraprovinci new yorker 26yearold rees witherspoon hand inject pure fantasi charact melani carmichael massiv infus oldfashion hollywood magic'
# 1	0.00	b'irwin earnest hard resist plea spare wildlif respect environ far wors messag teach young audienc probabl perfectli happi sloppi slapstick comedi'
# 1	0.00	b'never dull alway look good'
# 1	0.00	b'there way effect teach kid danger drug think project like unfortun rrate paid'
# 1	0.00	b'first shock thing soror boy actual watchabl even baffl funni'
# 1	0.00	b'movi captiv detail perform foreman barkingmad taylor thewliss smoothli sinist freddi bettanymcdowel hardey gangster'
# 0	1.00	b'film feel formula plot pace typic hollywood warmovi stuff perform elicit sens deja vu awe'
# 0	1.00	b'marqui de sade couldnt dull person film make'
# 1	0.00	b'movi good job lay major issu encount journey life'
# 1	0.00	b'moment hilar'
# 0	1.00	b'road perdit love strang excel'
# 1	0.00	b'moment broken charact studi rich emot textur journey doesnt realli go anywher'
# 0	1.00	b'forc familiar thoroughli condescend'
# 0	1.00	b'simpl good'
# 1	0.00	b'new zealand comingofag movi isnt realli anyth rich lusciou care'
# 1	0.00	b'dens charact contain thrill moment'
# 1	0.00	b'littl eye best littl horror movi ive seen year'
# 1	0.00	b'biggest problem movi nearli long enough'
# 0	1.00	b'well funnier'
# 1	0.00	b'movi occasion threaten becom didact ground realiti charact go edg touch humor unexpect plot twist alway pull back'
# 0	1.00	b'career curio major work'
# 0	1.00	b'hollywood answer air ball'
# 1	0.00	b'like old warner bro costum jive sex could movi errol flynn alway want make though bett davi cast joan would kill'
# 0	1.00	b'though goe anyon seen hunger cat peopl find littl new tasti perform vincent gallo lift tale cannib lust ordinari'
# 1	0.00	b'great cast wonder sometim confus flashback movi grow dysfunct famili'
# 0	1.00	b'incoher jumbl film that rare entertain could'
# 1	0.00	b'pretti good littl movi'
# 0	1.00	b'tone shift abruptli tens celebratori soppi'
# 0	1.00	b'human natur short isnt nearli funni think neither smart'
# 0	1.00	b'except act exercis except dark joke wonder anyon saw film allow get made'
# 0	1.00	b'pivot narr point ripe film cant help go soft stinki'
# 1	0.00	b'arm game support cast pitchperfect forster alway hilari meara levi like mike shoot score namesak proud'
# 0	1.00	b'joli perform vanish somewher hair lip'
# 1	0.00	b'addit score high origin plot put togeth familiar theme famili forgiv love new way lilo stitch number asset commend movi audienc innoc jade'
# 1	0.00	b'larg mr kilmer movi strongest perform sinc door'
# 0	1.00	b'put primit murder insid hightech space station unleash pandora box special effect run gamut cheesi cheesier cheesiest'
# 0	1.00	b'dumb cheesi may cartoon look almost shakespearean depth breadth watch digitaleffectsheavi suppos familyfriendli comedi'
# 0	1.00	b'say hi lover wake morn'
# 0	1.00	b'undistinguish attempt make classic theater piec cinemat'
# 0	1.00	b'worthless pseudorockvideo open idioci last frame'
# 0	1.00	b'one staggeringli wellproduc joylessli extravag pictur keep whoosh one visual marvel next hastili emptili'
# 0	1.00	b'left stori tri grab us keep let go wrong moment'
# 1	0.00	b'halloween resurrect isnt exactli qualiti cinema isnt nearli terribl cold'
# 1	0.00	b'decasia happen alreadi mani silent movi newsreel like unexpect thing die shower blackandwhit psychedelia quit beauti'
# 0	1.00	b'easi love robin tunney she pretti act get harder harder understand choic'
# 0	1.00	b'enough throwaway refer faith rainbow plant smilebutton face segment populac made walk rememb nich hit'
# 1	0.00	b'ask noth audienc sit back enjoy coupl great actor ham'
# 0	1.00	b'mostli shafer cowrit gregori hinton lack strongmind viewpoint sens humor'
# 0	1.00	b'rare film titl serv dire warn'
# 1	0.00	b'fairli selfawar dumb'
# 1	0.00	b'readymad midnight movi probabl wont stand cold light day right condit goofi entir wholesom fun'
# 1	0.00	b'tsai mingliang ghost pain awar notb'
# 1	0.00	b'watch film feel isnt mainli suspens excit domin feel someth like nostalgia'
# 0	1.00	b'alway rememb 911 terrorist attack see film tell there reason anyon bother rememb'
# 0	1.00	b'britney perform fault luci dull girl that'
# 1	0.00	b'high crime know mistak bad movi make determin make mayb nobil sort'
# 1	0.00	b'firstclass road movi prove run away home ego problem go'
# 0	1.00	b'shock reveal filmmak bottomless pit selfabsorpt'
# 1	0.00	b'movi real anarch flair'
# 0	1.00	b'imposs even categor smutti guilti pleasur'
# 0	1.00	b'enter bizarr realm director adrian lyne hold sway relationship simultan broadli metaphor oddli abstract excruciatingli liter'
# 1	0.00	b'cast topnotch predict plenti femal audienc member drool michael idemoto michael'
# 0	1.00	b'suppos humor alltoohuman look hope breed certain kind mad strength never quit add'
# 1	0.00	b'like go hous parti watch host defend froth exgirlfriend dont want call cop want call domino'
# 1	0.00	b'devote french cinema safe conduct rich period minutia like die go celluloid heaven'
# 1	0.00	b'dramat crisi doesnt alway succeed quest taken serious huppert volatil perform make rivet movi experi'
# 0	1.00	b'plod along minu twist humor eyepop visual made miik cult hero'
# 1	0.00	b'much movi pictur book big screen isnt favorit seri still enjoy enough recommend'
# 1	0.00	b'lifeaffirm vulgar mean like'
# 0	1.00	b'lost dramat convict underli best comedi'
# 1	0.00	b'fuller would sure call gutsi time exhilar movi great yarn'
# 0	1.00	b'take sudden turn devolv bizarr sort romant comedi steven shainberg adapt mari gaitskil harrow short stori brilliantli play deepli unsettl experi'
# 0	1.00	b'devolv deriv lean badlyrend cgi effect'
# 0	1.00	b'kept think enjoy wasnt'
# 0	1.00	b'film needlessli opaqu intro take doeey crudup pre911 new york onto crosscountri road trip homer kind'
# 1	0.00	b'far imagin ambiti trivial cashin featur nickelodeon made anim tv seri'
# 0	1.00	b'firsttim director joo pedro rodrigu unwilling defin hero background motiv becom frustrat film goe'
# 0	1.00	b'verbinski implement everi hackartist trick give us ookyspooki'
# 1	0.00	b'color sens stuart littl 2 immedi obviou pleasur would count littl movi werent beauti shape delic calibr tone'
# 0	1.00	b'film strictli routin'
# 0	1.00	b'home alon film stage like rosemari babi wellconceiv either film'
# 0	1.00	b'charact zigzag suffici develop support film construct around'
# 0	1.00	b'actress may work back stori women portray convincingli viewer dont get enough background charact involv individu rather type'
# 0	1.00	b'issu faith explor deepli'
# 0	1.00	b'pleas someon stop eric schaeffer make anoth film'
# 0	1.00	b'robin william depart fun friendli demeanor exchang darker unnerv role'
# 1	0.00	b'stori nice twist end backstori littl tire perform solid mere lack origin make great movi'
# 1	0.00	b'compel mix trial movi escap movi unexpect fabl ensur film never feel draggi'
# 1	0.00	b'open contriv banter clich loos end screenplay come second half'
# 0	1.00	b'hollywood taken quit nosed alfr hitchcock imagin flight shyamalan selfimport summer fluff'
# 1	0.00	b'emerg clearer view gear justic grind death report come share airtim alongsid farm report'
# 1	0.00	b'watch spirit away like watch eastern imagin explod'
# 0	1.00	b'soso entertain'
# 0	1.00	b'kind film leav scratch head amaz fact mani talent peopl could particip illadvis poorli execut idea'
# 0	1.00	b'sight name bruce willi bring mind imag violent battlefield action pictur film lot mindmayb much'
# 0	1.00	b'unwieldi contrapt'
# 0	1.00	b'see peopl thought hard mothman propheci'
# 0	1.00	b'burn fifth beersoak film feel almost everi possibl way write direct soggi perform toss'
# 1	0.00	b'despit titl punchdrunk love never heavyhand jab employ short care place deadcent'
# 0	1.00	b'rashomonfordipstick tale'
# 1	0.00	b'often gruell heartbreak wit seldahl wollter sterl perform rais far level usual maudlin diseas movi'
# 1	0.00	b'one left even aw act commit overwhelm sad feel made way bloodstream'
# 1	0.00	b'summer overrun movi domin cgi alien super hero revigor mind see featur concentr peopl project script charact hold sway'
# 1	0.00	b'even climact hourlong cricket match boredom never take hold'
# 1	0.00	b'count mont cristo okay sure classic like novel upon base'
# 0	1.00	b'glaze tawdri bmovi scum'
# 1	0.00	b'beauti anim epic never dull'
# 0	1.00	b'ensu much bloodsplatt mass druginduc bowel evacu nonetoofunni commentari cultur distinct american brit'
# 1	0.00	b'uncertain start murder hit gener sustain higher plateau bullock memor first interrog gosl'
# 0	1.00	b'lush beauti photograph somebodi suggest still might make nice coffe tabl book ultim youll leav theater wonder peopl matter'
# 1	0.00	b'prove mainli south korean filmmak make undemand action movi alacr hollywood counterpart'
# 1	0.00	b'one best exampl treat subject your fulli awar examin much like photo didnt know taken'
# 0	1.00	b'mildli entertain'
# 1	0.00	b'movi hit first scene know go trip igbi goe one movi'
# 1	0.00	b'mark respect summer blockbust one two thing unadulter thrill genuin laugh'
# 0	1.00	b'film depress life'
# 1	0.00	b'though equal solipsist tone movi enough vital justifi notion creat screen adapt evan saga hollywood excess'
# 1	0.00	b'day great bond movi good bond movi still make much better typic bond knockoff'
# 0	1.00	b'put air hal hartley wannab film without vital comic ingredi hilari writerdirector'
# 1	0.00	b'sometim blood seem tire protagonist still puls never disappear entir pictur cross finish line wind still game'
# 1	0.00	b'oldworld meetsnew mesh incarn movi soundtrack joy effus disco bollywood end monsoon wed sent spirit soar theater'
# 1	0.00	b'like bond outing recent year stunt outlandish border cartoonlik heavi relianc cgi technolog begin creep seri'
# 1	0.00	b'weird arrest littl ride'
# 0	1.00	b'there one decent perform cast one clever line dialogu'
# 0	1.00	b'sheridan take author schoolboy memoir rather toothless take hard young life'
# 1	0.00	b'modernday royal noth guy come scandal fairi tale princess marri polit reason live happili ever'
# 0	1.00	b'veloc repres everyth wrong independ film commodifi soldout concept american filmmak scene'
# 0	1.00	b'observ intellig constantli vie pretens sometim plain wacki implaus throughout maelstrom'
# 0	1.00	b'appar writerdirector attal thought need cast moviestar wife sit around drawer justifi film'
# 0	1.00	b'everybodi love david goliath stori one told almost entir david point view'
# 0	1.00	b'doubt film ratchet stir soundtrack throw fishoutofwat gag let clich dialogu rip els doggi wink'
# 0	1.00	b'live testament power eccentr strang fact isnt good almost besid point'
# 0	1.00	b'director oliv parker labor hard whip life import earnest probabl pull muscl two'
# 1	0.00	b'cast come even movi doesnt'
# 1	0.00	b'entir memor movi certainli easi watch'
# 0	1.00	b'great piti respons didnt cut loss retitl adventur directtovideo nash send proper home'
# 0	1.00	b'insight dream world teen life electron express cyber cultur film give quarter anyon seek pull cohes stori 2 12hour run time'
# 0	1.00	b'entertain dispos hannabarbera halfhour cartoon ever'
# 1	0.00	b'simpli cant recommend enough'
# 0	1.00	b'got heart right place also wilt awhil'
# 1	0.00	b'borrow bit classic wait dark extrem term style movi class'
# 1	0.00	b'may sound like mere diseaseof theweek tv movi song martin made infinit wrench perform reallif spous seldahl wollter'
# 0	1.00	b'mildli curiou fear put sleep bewild artsi often pointless visual'
# 1	0.00	b'here yet anoth studio horror franchis muck storylin glitch casual fan could correct sleep taken stylish energet oneshot queen damn said suck'
# 0	1.00	b'well beij bicycl begin spin wheel'
# 0	1.00	b'name woodi allen guarante someth fresh sometim funni usual genuin worthwhil hollywood end depress experi'
# 0	1.00	b'familiar basic sort cautionari tale old angel dirti face appear 1938'
# 1	0.00	b'pleasur read lip like see seri perfect black pearl click togeth form string drawn dark luster'
# 0	1.00	b'children christian otherwis deserv hear full stori jonah despair agon catch22 glori even spend year tri comprehend'
# 1	0.00	b'caviezel embodi transform charact complet'
# 0	1.00	b'uneasi mishmash style genr'
# 1	0.00	b'beguil slowmov parabl collis past present remot seacoast iran'
# 1	0.00	b'dog soldier doesnt transcend genr embrac energ take big bloodi chomp'
# 0	1.00	b'citi sea gritti polic thriller dysfunct famili dynam one could wish wash despit project prime mysteri'
# 0	1.00	b'portray modern women way director davi done unthink'
# 1	0.00	b'asid minor tinker movi probabl love 1994 except look even better'
# 1	0.00	b'succe bullock grant made share silver screen'
# 1	0.00	b'thumb paxton fall hollywood trap make vaniti project noth new offer'
# 0	1.00	b'hard may believ earth surprisingli similar teen drama better film'
# 0	1.00	b'rule attract get us drunk parti favor sober us transpar attempt moral'
# 0	1.00	b'hollow joke told cinemat gymnast much fun embellish misanthrop tale actual engag'
# 0	1.00	b'busi urban comedi clearli zhang fort directori touch neither light magic enough bring kind whimsi'
# 0	1.00	b'surpris heavyweight joel silver robert zemecki agre produc assum director pictur cavort ladi underwear'
# 1	0.00	b'refreshingli incis grant first time hell probabl appeal guy girlfriend drag movi hugh factor'
# 0	1.00	b'spi kid 2 island lost dream writerdirectorproduc robert rodriguez cobbl togeth film feel like sugar high gone awri'
# 0	1.00	b'comedi drama romanc cartoon'
# 1	0.00	b'script smart cloy'
# 0	1.00	b'hokey manipul bland wonder bread dip milk also absolut last thing need hollywood us preach'
# 1	0.00	b'divers artist repres term style ethnic prevent proceed feel repetiti appropri brief 40minut run time'
# 0	1.00	b'much move emot tumult franoi michl relationship depend lot interest likabl find'
# 1	0.00	b'despit stori predict enough make sound music play like nailbit thriller heart much right place difficult get realli peev'
# 0	1.00	b'egoyan work often elegantli consid variou level realiti use shift point view construct film labyrinthin defeat larger purpos'
# 1	0.00	b'feelgood movi feel movi feel good feel sad feel piss end feel aliv'
# 0	1.00	b'perri fist bull moor farm matter time get upper hand matter heart'
# 0	1.00	b'hit andmiss affair consist amus outrag funni cho may intend imagin one might hope'
# 1	0.00	b'like best godard movi visual ravish penetr impenetr'
# 1	0.00	b'movi thesi eleg technolog mass surprisingli refresh'
# 0	1.00	b'certain base level blue crush deliv promis well enough recommend'
# 0	1.00	b'long repetit take way mani year resolv total winner'
# 0	1.00	b'deliber devotedli construct far heaven pictur postcard perfect neat new pinlik obvious recreat reson'
# 1	0.00	b'audienc advis sit near back squint avoid notic truli egregi lipnonsynch otherwis product suitabl eleg'
# 0	1.00	b'textbook live quiet desper'
# 1	0.00	b'grossout gag color set piec cours stultifyingli contriv styliz half still get job done sleepi afternoon rental'
# 1	0.00	b'like less dizzili gorgeou companion mr wong mood love much hong kong movi despit mainland set'
# 1	0.00	b'gai come closer actress rememb personifi independ purest ye intimid form'
# 1	0.00	b'merchant effect translat naipaul live mix charact page screen'
# 0	1.00	b'best say uninspir bare give one paus consid dreck right'
# 0	1.00	b'visual sumptuou intellectu stultifi'
# 1	0.00	b'think gidget muscl lot smart endear easi watch'
# 0	1.00	b'there disturb great white hope underton side heaven subtli undermin messag christian love compass'
# 1	0.00	b'jacki chan movi guilti pleasur he easi like alway leav us laugh'
# 1	0.00	b'visionari marvel lack depth storytel usual found anim like'
# 1	0.00	b'notori c h oodl vulgar highlight'
# 1	0.00	b'like mike doesnt win point origin succeed follow feelgood formula win style offer target audienc urban kid welcom role model optim'
# 1	0.00	b'hayn fanat fetish everi bizarr oldmovi idiosyncrasi monast devot your sure applaud look commit'
# 0	1.00	b'kid discov new collect parent suspect theyr watch 76minut commerci'
# 0	1.00	b'extrem prevent us take messag serious stepford wive mental doesnt work modern context'
# 0	1.00	b'despit auteuil perform rather listless ambl middl road themat ironi obviou sexual polit smug'
# 1	0.00	b'noth detract affect moral favorit friend friend thick thin'
# 1	0.00	b'reinforc talent screenwrit charli kaufman creator adapt john malkovich'
# 1	0.00	b'actress find rhythm protect script bad idea awkward'
# 0	1.00	b'film overal mood focu interest constantli unfulfil'
# 0	1.00	b'ultim make windtalk disappoint superfici way deal stori'
# 1	0.00	b'rather shapeless good time'
# 0	1.00	b'film great premis great premis'
# 1	0.00	b'celebr group play spark nonconform glanc vividli back hibiscu grandli call angel light'
# 0	1.00	b'skirmish power wage among victim predat settl undistinguish rhythm artifici suspens'
# 1	0.00	b'windtalk shapelessli gratifi kind movi invit pick apart fault even admit somehow hit live'
# 0	1.00	b'punchdrunk love convinc brillianc person youd want smash face'
# 1	0.00	b'kind effect creepyscari thriller fixat far corner screen time nerv cant take'
# 1	0.00	b'one hour photo intrigu snapshot one man delus bad doesnt flash insight'
# 0	1.00	b'star help give spark chase ami chang lane fall flat think man cia agent jack ryan summer new action film sum fear'
# 0	1.00	b'neither funni suspens particularli welldrawn'
# 0	1.00	b'innocu enough make even jeanclaud van damm look good'
# 0	1.00	b'parti scene deliv tawdri kick rest film dudsvil'
# 1	0.00	b'writerdirector walter hill hypermasculin element abl inject real vital even art pulpi concept mani hand would complet forgett'
# 0	1.00	b'human natur initi succe allow go crazi ultim fail spin control'
# 0	1.00	b'tv style murder mysteri big screen moment includ one seem made differ film altogeth'
# 0	1.00	b'amid shock curios factor film corni examin young actress tri find way'
# 0	1.00	b'total overwrought deepli bias wholli design make feel guilti ignor filmmak clearli believ greatest musician time'
# 1	0.00	b'like egoyan work ararat fierc intellig uncommonli ambiti'
# 0	1.00	b'one pussyass world even killerthril revolv around group therapi session'
# 1	0.00	b'ill put way your mood melodrama narrat talk fish movi'
# 0	1.00	b'film oldfashion occasion charm subtl boldfac'
# 0	1.00	b'fanboy brought life big screen'
# 1	0.00	b'princess sorvino glide grace male persona femal without miss beat ben kingsley truli funni play kind ghandi gone bad'
# 1	0.00	b'frailti written well even simpl goddammit near end take whole mean'
# 0	1.00	b'film take long get good stuff take long figur next'
# 1	0.00	b'ye good rememb fact even better'
# 1	0.00	b'movi wear make misti even dont want'
# 0	1.00	b'there excel 90minut film unfortun run 170'
# 0	1.00	b'notsodivin secret yaya sisterhood hefti help refri green tomato'
# 1	0.00	b'know plot littl crazi held interest start finish'
# 1	0.00	b'wellround tribut man whose achiev complex reach far beyond end zone'
# 0	1.00	b'may easi swipe take barbershop doesnt make cut'
# 0	1.00	b'without nonstop techno existenti overton kieslowski moral tale maelstrm anoth winter sleeper'
# 1	0.00	b'aaa action xxx blast adrenalin rate eee excit vin diesel man'
# 0	1.00	b'even diehard fan japanes anim find one challeng'
# 1	0.00	b'bon apptit like splendid meal red dragon satisfi ripe recip inspir ingredi certifi cuisin palat present'
# 0	1.00	b'film sort cinemat high crime one bring militari courtroom drama low'
# 1	0.00	b'quit divert nonsens'
# 0	1.00	b'unimagin nasti glibli cynic piec work'
# 1	0.00	b'remind use make movi also sometim still made'
# 1	0.00	b'move quickli adroitli without fuss doesnt give time reflect inan cold war dated premis'
# 1	0.00	b'movi mix cornpon cosa nostra find nice rhythm'
# 1	0.00	b'seduct teas thriller get job done scorcher'
# 0	1.00	b'film wasnt preachi femin book'
# 1	0.00	b'depend upon reaction movi may never abl look red felt sharpi pen without disgust thrill giggl'
# 0	1.00	b'jaglom offer nonetooorigin premis everyon involv moviemak con artist liar'
# 1	0.00	b'downward spiral come pass auto focu bear typic junki opera'
# 0	1.00	b'cute though terribl funni your six year old'
# 0	1.00	b'rather quickli film fall sooth formula brotherli conflict reconcili'
# 1	0.00	b'suffer timid pars barnsid target son tri breach gap relationship father'
# 1	0.00	b'actionadventur spacebas homag robert loui stevenson treasur island fire plasma conduit'
# 1	0.00	b'dare mesmer exceedingli hard forget'
# 1	0.00	b'twentysometh hotsi make movi live harddriv narciss given world wed live argento hollywood counterpart much imagin nerv'
# 1	0.00	b'small movi big impact'
# 1	0.00	b'courag wonder big question sincer devot risk seem slow pretenti think gambl worth promis'
# 1	0.00	b'uniqu resid home movi peopl live carv comfort nich world kind enough share'
# 0	1.00	b'farc parodi comedi premis isnt comparison realiti much commentari knowledg film'
# 1	0.00	b'ok movi someth sitcom apparatu line work humor point actor humanli engag'
# 0	1.00	b'thirdperson stori told hollywood much ordinari'
# 0	1.00	b'devoid qualiti made first film special'
# 1	0.00	b'your look intellig movi releas pent anger enough ticket need'
# 0	1.00	b'supposedli base upon real least soberli report incid film end larg human tragedi ala get even half interest'
# 1	0.00	b'vincent gallo right home french shocker play usual bad boy weirdo role'

# %%
misclassified_NB = []
print('Truth Predicted Review')

for x, y in zip(x_test, y_test):
    y_hat = predict_review_NB(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        misclassified_NB.append(process_text(x))
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(process_text(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Review
# 0	1.00	b'effort sincer result honest film bleak hardli watchabl'
# 0	1.00	b'movi lie cheat love friend betray'
# 0	1.00	b'even accept right frame mind provid much lenienc'
# 0	1.00	b'motion pictur portray ultim passion other creat ultim thrill men black ii achiev ultim insignific scifi comedi spectacl whifflebal epic'
# 0	1.00	b'blanket statement dimestor rumin vaniti worri rich sudden wisdom film becom sermon run time'
# 1	0.00	b'total success someth true film addict want check bet'
# 0	1.00	b'bravo reveal true intent film care select interview subject construct portrait castro predominantli charit seen propaganda'
# 1	0.00	b'birthday girl doesnt tri surpris us plot twist rather seem enjoy transpar'
# 0	1.00	b'group selfabsorb women mother daughter featur film dont think noth wrong perform whiney charact bug'
# 0	1.00	b'predict bland comfort food appeal film pleasant enough dish'
# 0	1.00	b'mindless junk like make appreci origin romant comedi like punchdrunk love'
# 0	1.00	b'american adobo heart palat right place brain littl scatter ditsi even'
# 1	0.00	b'de niro murphi make showtim savori hilari guilti pleasur mani recent movi season'
# 1	0.00	b'confound solemnli advanc daringli preposter thesi act act'
# 0	1.00	b'martin scorses cria um espetculo visual que no possui alma um film esteticament belo ma emocionalment frio'
# 1	0.00	b'high crime steal freeli movi combin enough dispar type film cant help engag audienc'
# 0	1.00	b'tough astring darkli funni well also gener untidi condescend mild impact rather stun'
# 0	1.00	b'russel lack visual panach comic touch perhap budget sommerss titlebout featur'
# 0	1.00	b'execr'
# 0	1.00	b'captur conceptu process doesnt add suffici explan final danc work select becam final form'
# 0	1.00	b'standard policeori drama de niro particip would like wound tnt origin'
# 0	1.00	b'perfectli enjoy instantli forgett noth write home'
# 0	1.00	b'affleck mere creat outlin role still need grow role ford effortlessli fill author'
# 0	1.00	b'movi load good intent zeal squeez action emot alltoofamiliar dramat arc holocaust escap stori minac drain movi individu'
# 1	0.00	b'one funnier movi town'
# 0	1.00	b'connect stori breitbart hanussen actual fascin filmmak invinc movi justic'
# 0	1.00	b'director capabl cast appear caught headi whirl new ageinspir good intent spell cast isnt least bit mesmer'
# 0	1.00	b'horrif movi experi ive sinc cant stop music may well call jarjar bink movi pain'
# 0	1.00	b'feel like work someon may inde final age past prime perhap realiz want like peopl still give work'
# 0	1.00	b'rare much money deliv littl entertain'
# 1	0.00	b'farcic element seem pat familiar hold interest yet divert grim messag good one'
# 0	1.00	b'cox offer plenti glimps exist photo movi nijinski instead director treat us aimless hodgepodg'
# 0	1.00	b'despit juliet stevenon attempt bring cohes pamela emot roller coaster life enough give film substanc desper need'
# 0	1.00	b'danc completist'
# 1	0.00	b'although doesnt alway hang togeth violenc whimsi dont combin easili cherish certainli isnt dull'
# 0	1.00	b'eastwood icon moviemak one best actor director produc around respons excel work even hero stumbl sometim'
# 1	0.00	b'hard especi grate freedom film like'
# 1	0.00	b'13 convers hold goodwil close rel slow come point'
# 0	1.00	b'pictur seem uncertain whether want acid allmal eve lush swoon melodrama intermezzo strain'
# 1	0.00	b'see inevit hollywood remak flatten odd intrigu wrinkl'
# 0	1.00	b'even ultim disappoint pictur matine admiss worth funni keep afloat'
# 0	1.00	b'wrap classic motherdaught struggl recycl paper shini new bow audienc tell new least look pretti'
# 0	1.00	b'campi work straight drama violent sordid function comedi vulgar truli thank oneofakind work'
# 1	0.00	b'gangster movi capac surpris'
# 0	1.00	b'best describ know last winter'
# 0	1.00	b'trivial profound hyperclich sincer'
# 0	1.00	b'succe provid disquiet world longdread complet polic academi seri'
# 1	0.00	b'hatosi portray young brendan usual intellig subtleti mention convinc brogu'
# 1	0.00	b'definit improv first blade sinc doesnt take deadli serious'
# 0	1.00	b'strident ineleg messagemovi postur'
# 0	1.00	b'handl correctli wild play masterpiec eleg wit artific ala collaps like overcook souffl'
# 0	1.00	b'though ganesh success midlevel sort way there noth strike fascin metaphor signific career rate two hour attent'
# 0	1.00	b'humor isnt sharp effect innov stori imagin origin could wors'
# 0	1.00	b'christian bale quinn leather clad grungepir hairdo like gandalf windtunnel simpli astound corblimeyluvaduck cockney accent'
# 0	1.00	b'play like unbalanc mixtur graphic combat footag almost saccharin domest interlud pure hollywood'
# 0	1.00	b'well made indieflick need trim chemistri star'
# 1	0.00	b'ok arthous power script perform come whole damn thing didnt get moral hackl'
# 0	1.00	b'gener famili comedi unlik appreci anyon outsid under10 set'
# 0	1.00	b'full frontal open today nationwid could almost classifi movieindustri satir lack gener inclus genr definit disingenu featur'
# 1	0.00	b'impress flaw effort indic real talent'
# 1	0.00	b'wont argu anyon call slacker dumb insult childish laugh much didnt mind'
# 1	0.00	b'baran shockingli devoid typic majid majidi shoelov crippl children'
# 0	1.00	b'brisk wang pace none excel cast given air breath'
# 0	1.00	b'anthoni hopkin big deal weve alreadi seen prequel silenc lamb hannib better first time'
# 0	1.00	b'normal rohmer talki film fascin move set past reli histor text lose rich character make film memor'
# 0	1.00	b'despit gulp film fuzzi huggi'
# 0	1.00	b'havent seen hilar sinc say isnt'
# 0	1.00	b'halfway movi humor dwindl replac dramat scene jar deepli place could probabl lightheart comedi'
# 1	0.00	b'whole cast look much fun slapstick antic silli street patoi toss around obscur express like bellini mullinski compact 86 minut breez'
# 1	0.00	b'pain horrifi oppress tragic film miss'
# 0	1.00	b'piano teacher sort movi discourag american audienc ever want see anoth foreign film'
# 0	1.00	b'take away controversi much watchabl mexican soap opera'
# 0	1.00	b'watch film nearli provok take life hour win best pictur might'
# 1	0.00	b'estrogen opera intens feminin serv antidot cannier doppelgang diesel xxx flexathon'
# 1	0.00	b'stori old scari one monster make vengeanc take'
# 0	1.00	b'aggress cheeri pollyana would reach barf bag'
# 0	1.00	b'viewer ask often suspend belief holm perform film would total washout'
# 0	1.00	b'scriptwrit less menac societi film charact'
# 1	0.00	b'gambl throw basketbal game money isnt new plot fact toback use black white toback derang immediaci make seem fresh'
# 0	1.00	b'go far enough humor stock idea stand particularli memor even funni'
# 0	1.00	b'lessthancompel documentari yiddish theater clan'
# 0	1.00	b'christ allegori doesnt work foundat'
# 0	1.00	b'process comedi chop suey'
# 1	0.00	b'work part avoid stupid clich formula pothol befal brethren'
# 1	0.00	b'deflat end asid there much recommend film'
# 0	1.00	b'mindless yet impress lean spinoff last summer bloat effect fest mummi return'
# 0	1.00	b'one decadesspan histor epic strive intim social encompass fail justic either effort three hour screen time'
# 1	0.00	b'never fail engag us'
# 0	1.00	b'funniest american comedi sinc graffiti bridg'
# 1	0.00	b'everyth work averag higher mari recent comedi'
# 0	1.00	b'present good case fail provid reason us care beyond basic dictum human decenc'
# 1	0.00	b'must end world best film far year franchis sequel star wesley snipe'
# 1	0.00	b'without de niro citi sea would slip wave drag back singlehand'
# 1	0.00	b'convent wellcraft film histor legal battl ireland man right rais children'
# 1	0.00	b'could daytim soap opera actual compel look young woman tragic odyssey'
# 1	0.00	b'scorses bold imag gener smart cast ensur gang never letharg movi hinder central plot that pepper fals start popul charact nearli imposs care'
# 0	1.00	b'real world actor uncharismat beauti would rsum load credit like girl bar 3'
# 0	1.00	b'charm overli complic'
# 1	0.00	b'dont expect surpris checklist teamwork clich'
# 0	1.00	b'unclassifi aw studi self audienceabus'
# 0	1.00	b'make movi depth man lack evid us answer clear easili end well enough'
# 1	0.00	b'even though mani guy less ador lament pretti much selfcent there someth vital movi'
# 1	0.00	b'long dishonor histori quicki teenpop exploit like mike stand partli synthet decenc'
# 0	1.00	b'dont think movi love women'
# 1	0.00	b'meticul uncov trail outrag forc craven conceal'
# 0	1.00	b'singularli offput romant comedi'
# 1	0.00	b'una pelcula oscura precisa por momento grandiosa casi siempr conmovedora'
# 0	1.00	b'wellmad mushheart'
# 0	1.00	b'bartlett hero remain reactiv cipher open man head heart imagin reason film made'
# 0	1.00	b'despit strong perform never rise level telanovela'
# 0	1.00	b'perplex watch unfold astonish lack passion uniqu'
# 1	0.00	b'realli happen question philosoph filmmak filmmak need engag audienc'
# 0	1.00	b'juli davi kathi lee gifford film director sadli prove ego doesnt alway go hand hand talent'
# 0	1.00	b'definit crowdpleas roman colosseum'
# 0	1.00	b'film center hold'
# 1	0.00	b'trap wont score point polit correct may caus parent sleepless hour sign effect'
# 0	1.00	b'cut hollywood satir instead fresh last week issu varieti'
# 0	1.00	b'movi that overbear overthetop famili depict'
# 1	0.00	b'legendari irish writer brendan behan memoir borstal boy given love screen transferr'
# 1	0.00	b'harsh work piec storytel intellectu exercis unpleas debat that given drive narr that act believ noth less provoc piec work'
# 0	1.00	b'influenc chiefli human greatest shame realiti show realiti show god sake crime punish chainsaw'
# 0	1.00	b'would prefer transfer hall mr holland class music robin williamss lectur could listen teacher humor passion verv'
# 1	0.00	b'much see horribl also undeni exceedingli clever'
# 1	0.00	b'despit oldhat setup predict plot empir still enough moment keep entertain'
# 0	1.00	b'selfstyl athlet bang brain ground frequent furious capac explain gone way natur instinct selfpreserv'
# 1	0.00	b'triumph love silli movi silli pedigre'
# 0	1.00	b'case sacr bleu magnifiqu'
# 0	1.00	b'behan memoir great materi film rowdi brawni lyric best irish sens sheridan settl lugubri romanc'
# 0	1.00	b'seem film art rip peopl without ever let conscious know done'
# 1	0.00	b'shamelessli resort peerel sight gag might even caus tom green grimac still myer energi silli eventu prevail'
# 1	0.00	b'one nearli dread expect fact quit fun place'
# 1	0.00	b'much better documentari reveal emot surpris pedestrian english titl would believ'
# 0	1.00	b'lessthanthril thriller'
# 1	0.00	b'begin end scene terrifi im still stun ive decid leav light everi night'
# 1	0.00	b'hardli masterpiec introduc viewer good charit enterpris interest real peopl'
# 1	0.00	b'taut psycholog thriller doesnt wast moment twohour run time'
# 0	1.00	b'made discern craft monstrous sanctimoni deal childhood loss'
# 1	0.00	b'ali graduat littl screen big far less pain open scene encount overamor terrier'
# 0	1.00	b'credit must given harland william michael rosenbaum barri watson inject far goodnatur spirit talent project deserv'
# 1	0.00	b'concept idea thrill ride fascin look futur bladerunn one highconcept sci fi adventur attempt screen'
# 1	0.00	b'clint eastwood blood work lot like wellmad pb j sandwich familiar fairli unev boast real surpris still quit tasti invit'
# 1	0.00	b'hit everi clich weve come expect includ assumpt crazi peopl innoc childlik inher funni'
# 0	1.00	b'piano teacher like titl charact repellantli control'
# 0	1.00	b'fessenden continu interest work would nice see could make decent budget problem wendigo effect moment isnt realli one resourc'
# 1	0.00	b'greengrass work mullan script forgo larger sociopolit pictur situat northern ireland favour approach throw one pulsat thick truli frighten situat'
# 1	0.00	b'make movi comedi way avoid seriou emot involv'
# 0	1.00	b'fill lowbrow humor gratuit violenc disturb disregard life'
# 0	1.00	b'endur love exhaust cinema'
# 0	1.00	b'certainli clever spot toolong spoofi updat shakespear macbeth doesnt sustain high enough level invent'
# 1	0.00	b'comedi swing jostl rhythm life'
# 0	1.00	b'holm terrif men hjejl quit appeal film fail make intrigu premis'
# 0	1.00	b'chocol factori without charli'
# 1	0.00	b'thing guy like evan your never quit sure selfpromot end truth begin watch movi your interest care'
# 0	1.00	b'movi strain stay light comic side issu despit difficulti deal destruct properti potenti life'
# 0	1.00	b'short sweet also anyth els slight tadpol pull back consequ action revel'
# 0	1.00	b'occasion interest mostli repetit look slice countercultur might best forgotten'
# 0	1.00	b'filmmak know pleas eye alway prettiest pictur tell best stori'
# 0	1.00	b'stori friendship proce way your watch soap opera rather chronicl up down accompani lifelong friendship'
# 0	1.00	b'surprisingli inert movi main charact travel back forth epoch'
# 0	1.00	b'fun psycholog mess austin power bump head way closet'
# 0	1.00	b'meticul mount exasperatingli wellbehav film tick kahlo lifetim mileston duti precis tax account'
# 1	0.00	b'apart anyth els one bestsustain idea ever seen screen'
# 0	1.00	b'film take materi human tragedi dress love costum southern california locat star power'
# 0	1.00	b'one set sens humor nerv speak'
# 0	1.00	b'addict film violenc form find anyth appreci'
# 0	1.00	b'culkin turn charact basic antiharri potter right gryffindor scarf'
# 0	1.00	b'your better stay home watch xfile'
# 0	1.00	b'weep futur good portion respect critic commun countri consid blue crush intellig film young women'
# 0	1.00	b'get caddyshack cross loyal order raccoon'
# 1	0.00	b'kind nervou film either give mild headach exhilar'
# 0	1.00	b'messag merit hand brutal honest individu like prophet jack might made point two regard life'
# 1	0.00	b'film that destin win wide summer audienc wordofmouth review far line find place among studio anim classic'
# 1	0.00	b'never dull alway look good'
# 1	0.00	b'there way effect teach kid danger drug think project like unfortun rrate paid'
# 1	0.00	b'writerdirector joe carnahan grimi crime drama manual precinct clich move fast enough cover clunki dialogu laps logic'
# 1	0.00	b'first shock thing soror boy actual watchabl even baffl funni'
# 0	1.00	b'road perdit love strang excel'
# 0	1.00	b'movi like sell old european candor old wink bold revel 2002 revel wilt'
# 0	1.00	b'forc familiar thoroughli condescend'
# 0	1.00	b'simpl good'
# 1	0.00	b'dens charact contain thrill moment'
# 1	0.00	b'biggest problem movi nearli long enough'
# 0	1.00	b'hollywood answer air ball'
# 0	1.00	b'though goe anyon seen hunger cat peopl find littl new tasti perform vincent gallo lift tale cannib lust ordinari'
# 1	0.00	b'pretti good littl movi'
# 0	1.00	b'tone shift abruptli tens celebratori soppi'
# 1	0.00	b'impress hybrid'
# 1	0.00	b'substitut onscreen chemistri friel pull string make william sink melancholia reaction william viscer gut punch'
# 0	1.00	b'part useless movi even great director helm'
# 0	1.00	b'joli perform vanish somewher hair lip'
# 0	1.00	b'put primit murder insid hightech space station unleash pandora box special effect run gamut cheesi cheesier cheesiest'
# 0	1.00	b'say hi lover wake morn'
# 1	0.00	b'real stori real peopl live live concern futur elderli mental handicap famili member'
# 0	1.00	b'one staggeringli wellproduc joylessli extravag pictur keep whoosh one visual marvel next hastili emptili'
# 1	0.00	b'paradiso rustedout ruin ultim collaps film final restor thirdemot belittl cinema classic sometim shorter better'
# 1	0.00	b'halloween resurrect isnt exactli qualiti cinema isnt nearli terribl cold'
# 0	1.00	b'forgett goodheart movi'
# 0	1.00	b'easi love robin tunney she pretti act get harder harder understand choic'
# 1	0.00	b'ask noth audienc sit back enjoy coupl great actor ham'
# 0	1.00	b'mostli shafer cowrit gregori hinton lack strongmind viewpoint sens humor'
# 1	0.00	b'fairli selfawar dumb'
# 1	0.00	b'readymad midnight movi probabl wont stand cold light day right condit goofi entir wholesom fun'
# 0	1.00	b'deepli seriou movi care passion subject often becom ponder teach histori lost intric connect multipl timelin stori'
# 1	0.00	b'watch film feel isnt mainli suspens excit domin feel someth like nostalgia'
# 0	1.00	b'alway rememb 911 terrorist attack see film tell there reason anyon bother rememb'
# 1	0.00	b'pleasur see seinfeld gripe biz buddi chri rock garri shandl colin quinn'
# 1	0.00	b'high crime know mistak bad movi make determin make mayb nobil sort'
# 0	1.00	b'shock reveal filmmak bottomless pit selfabsorpt'
# 1	0.00	b'formula familiar enjoy'
# 1	0.00	b'cho face amaz slapstick instrument creat scrapbook live mug shot'
# 0	1.00	b'stand there fine sex onscreen tens argu whole lot'
# 0	1.00	b'suppos humor alltoohuman look hope breed certain kind mad strength never quit add'
# 1	0.00	b'film problem short disappoint want stori go'
# 1	0.00	b'god bless crudup avers take easi hollywood road cash moviestar gorgeous'
# 1	0.00	b'like go hous parti watch host defend froth exgirlfriend dont want call cop want call domino'
# 0	1.00	b'plod along minu twist humor eyepop visual made miik cult hero'
# 1	0.00	b'much movi pictur book big screen isnt favorit seri still enjoy enough recommend'
# 1	0.00	b'lifeaffirm vulgar mean like'
# 0	1.00	b'lost dramat convict underli best comedi'
# 0	1.00	b'take sudden turn devolv bizarr sort romant comedi steven shainberg adapt mari gaitskil harrow short stori brilliantli play deepli unsettl experi'
# 1	0.00	b'far imagin ambiti trivial cashin featur nickelodeon made anim tv seri'
# 1	0.00	b'critic need good laugh tooextremefortv rendit notori mtv show deliv outrag sicken sidesplit good steam viscer heap'
# 0	1.00	b'home alon film stage like rosemari babi wellconceiv either film'
# 0	1.00	b'actress may work back stori women portray convincingli viewer dont get enough background charact involv individu rather type'
# 0	1.00	b'leer offer next littl insight intrigu subject'
# 0	1.00	b'issu faith explor deepli'
# 1	0.00	b'submarin drama earn right favor compar da boot'
# 0	1.00	b'robin william depart fun friendli demeanor exchang darker unnerv role'
# 1	0.00	b'stori nice twist end backstori littl tire perform solid mere lack origin make great movi'
# 1	0.00	b'open contriv banter clich loos end screenplay come second half'
# 0	1.00	b'hollywood taken quit nosed alfr hitchcock imagin flight shyamalan selfimport summer fluff'
# 1	0.00	b'emerg clearer view gear justic grind death report come share airtim alongsid farm report'
# 0	1.00	b'see robin william psycho killer think hmmmmm see movi think zzzzzzzzz'
# 0	1.00	b'sight name bruce willi bring mind imag violent battlefield action pictur film lot mindmayb much'
# 0	1.00	b'unwieldi contrapt'
# 0	1.00	b'much movi joint promot nation basketbal associ teenag rap adolesc posterboy lil bow wow'
# 1	0.00	b'remain solid somewhat heavyhand account neardisast done howard steadi imagin hand'
# 1	0.00	b'great parti'
# 0	1.00	b'see peopl thought hard mothman propheci'
# 0	1.00	b'would total loss two support perform take place movi edg'
# 1	0.00	b'despit titl punchdrunk love never heavyhand jab employ short care place deadcent'
# 0	1.00	b'rashomonfordipstick tale'
# 1	0.00	b'one left even aw act commit overwhelm sad feel made way bloodstream'
# 1	0.00	b'rude black comedi catalyt effect holi fool upon around cutthroat world children televis'
# 0	1.00	b'malon gift gener nightmarish imag hard burn brain movi narr hook way muddl effect chill guilti pleasur'
# 1	0.00	b'even climact hourlong cricket match boredom never take hold'
# 0	1.00	b'glaze tawdri bmovi scum'
# 1	0.00	b'may last tango pari'
# 0	1.00	b'name say jackass vulgar cheaplook version candid camera stage marqui de sade set'
# 1	0.00	b'beauti anim epic never dull'
# 0	1.00	b'ensu much bloodsplatt mass druginduc bowel evacu nonetoofunni commentari cultur distinct american brit'
# 1	0.00	b'workmanlik mayb still film element made three great scari time movi'
# 0	1.00	b'follow dream matter parent think socrat motion hemlock'
# 0	1.00	b'girl gone wild video boho arthous crowd burn sensat isnt definit countercultur document maker arent remov inquisit enough'
# 0	1.00	b'lush beauti photograph somebodi suggest still might make nice coffe tabl book ultim youll leav theater wonder peopl matter'
# 0	1.00	b'even harriss strong effort script give littl effect probe lear soulstrip breakdown'
# 1	0.00	b'movi hit first scene know go trip igbi goe one movi'
# 0	1.00	b'film depress life'
# 1	0.00	b'though equal solipsist tone movi enough vital justifi notion creat screen adapt evan saga hollywood excess'
# 1	0.00	b'day great bond movi good bond movi still make much better typic bond knockoff'
# 1	0.00	b'sometim blood seem tire protagonist still puls never disappear entir pictur cross finish line wind still game'
# 1	0.00	b'like bond outing recent year stunt outlandish border cartoonlik heavi relianc cgi technolog begin creep seri'
# 0	1.00	b'period stori cathol boy tri help jewish friend get heaven send audienc straight hell'
# 1	0.00	b'hard fairli judg film like ringu youv seen remak first mani effect horror element dampen familiar yet worthwhil'
# 0	1.00	b'observ intellig constantli vie pretens sometim plain wacki implaus throughout maelstrom'
# 0	1.00	b'amalgam fugit blade runner total recal without much energi tension'
# 0	1.00	b'everybodi love david goliath stori one told almost entir david point view'
# 1	0.00	b'absolut spooki lillard channel shagster right origin casey kasemfurnish voic'
# 0	1.00	b'kept much plot jettison stuff would make move experi peopl havent read book'
# 0	1.00	b'live testament power eccentr strang fact isnt good almost besid point'
# 0	1.00	b'director oliv parker labor hard whip life import earnest probabl pull muscl two'
# 1	0.00	b'cast come even movi doesnt'
# 0	1.00	b'great piti respons didnt cut loss retitl adventur directtovideo nash send proper home'
# 0	1.00	b'insight dream world teen life electron express cyber cultur film give quarter anyon seek pull cohes stori 2 12hour run time'
# 1	0.00	b'simpli cant recommend enough'
# 1	0.00	b'elegantli produc express perform six music number crystal key plot moment minut detail wonder dreamlik ecstasi'
# 0	1.00	b'got heart right place also wilt awhil'
# 1	0.00	b'borrow bit classic wait dark extrem term style movi class'
# 1	0.00	b'may sound like mere diseaseof theweek tv movi song martin made infinit wrench perform reallif spous seldahl wollter'
# 1	0.00	b'here yet anoth studio horror franchis muck storylin glitch casual fan could correct sleep taken stylish energet oneshot queen damn said suck'
# 0	1.00	b'well beij bicycl begin spin wheel'
# 0	1.00	b'name woodi allen guarante someth fresh sometim funni usual genuin worthwhil hollywood end depress experi'
# 0	1.00	b'often linger long irrelev engag gradual turn time long movi'
# 1	0.00	b'beguil slowmov parabl collis past present remot seacoast iran'
# 0	1.00	b'citi sea gritti polic thriller dysfunct famili dynam one could wish wash despit project prime mysteri'
# 0	1.00	b'portray modern women way director davi done unthink'
# 1	0.00	b'asid minor tinker movi probabl love 1994 except look even better'
# 1	0.00	b'thumb paxton fall hollywood trap make vaniti project noth new offer'
# 1	0.00	b'mildli entertain especi find comfort familiar hardli necessari enterpris'
# 0	1.00	b'iditarod last day felt like'
# 0	1.00	b'movi turn assaya homag gallic tradit qualiti fusti squar'
# 0	1.00	b'busi urban comedi clearli zhang fort directori touch neither light magic enough bring kind whimsi'
# 1	0.00	b'your mind set goofi comedi trooper entertain gross out bawdi comedi head game'
# 0	1.00	b'surpris heavyweight joel silver robert zemecki agre produc assum director pictur cavort ladi underwear'
# 1	0.00	b'refreshingli incis grant first time hell probabl appeal guy girlfriend drag movi hugh factor'
# 0	1.00	b'comedi drama romanc cartoon'
# 1	0.00	b'itll probabl best matur comedi 2002 summer season speak season pictur'
# 1	0.00	b'script smart cloy'
# 0	1.00	b'good movi spurt doesnt work import time'
# 0	1.00	b'much move emot tumult franoi michl relationship depend lot interest likabl find'
# 0	1.00	b'egoyan work often elegantli consid variou level realiti use shift point view construct film labyrinthin defeat larger purpos'
# 1	0.00	b'feelgood movi feel movi feel good feel sad feel piss end feel aliv'
# 0	1.00	b'hit andmiss affair consist amus outrag funni cho may intend imagin one might hope'
# 1	0.00	b'like best godard movi visual ravish penetr impenetr'
# 0	1.00	b'culkin exud none charm charisma might keep gener audienc even vagu interest bratti charact'
# 0	1.00	b'certain base level blue crush deliv promis well enough recommend'
# 0	1.00	b'deliber devotedli construct far heaven pictur postcard perfect neat new pinlik obvious recreat reson'
# 0	1.00	b'textbook live quiet desper'
# 0	1.00	b'gener forgett pleasant start finish'
# 1	0.00	b'grossout gag color set piec cours stultifyingli contriv styliz half still get job done sleepi afternoon rental'
# 0	1.00	b'weighti theme grave youngster stori steep fairi tale childish thing appeal much teenag'
# 1	0.00	b'merchant effect translat naipaul live mix charact page screen'
# 0	1.00	b'solondz two idea two movi couldnt realli figur flesh either slop em togeth'
# 0	1.00	b'visual sumptuou intellectu stultifi'
# 0	1.00	b'there someth entir convinc quiet american hold true movi titl charact play brendan fraser'
# 1	0.00	b'matur fatal attract complet indec propos relev 9  week unfaith intim univers cinema'
# 0	1.00	b'there disturb great white hope underton side heaven subtli undermin messag christian love compass'
# 1	0.00	b'jacki chan movi guilti pleasur he easi like alway leav us laugh'
# 1	0.00	b'rang laughoutloud hilari wonderwhat timeiti tediou'
# 1	0.00	b'notori c h oodl vulgar highlight'
# 0	1.00	b'unfortun experi actual watch movi less compel circumst make'
# 1	0.00	b'film consid approach subject matter calm thought agitprop thin character make failur straight drama'
# 0	1.00	b'despit auteuil perform rather listless ambl middl road themat ironi obviou sexual polit smug'
# 1	0.00	b'rare film whose reallif basi fact interest embellish need'
# 1	0.00	b'noth detract affect moral favorit friend friend thick thin'
# 1	0.00	b'actress find rhythm protect script bad idea awkward'
# 0	1.00	b'gunfest rock concert'
# 1	0.00	b'rather shapeless good time'
# 0	1.00	b'like hate love hell dunno'
# 0	1.00	b'perfectli accept perfectli bland compet act mean scari horror movi'
# 0	1.00	b'punchdrunk love convinc brillianc person youd want smash face'
# 1	0.00	b'notori c h cho prove stuff stand tall pryor carlin murphi'
# 1	0.00	b'ring worth look dont demand much cheap thrill halloween entertain'
# 0	1.00	b'sophist viewer refus admit dont like like call challeng fellow sophist'
# 1	0.00	b'one hour photo intrigu snapshot one man delus bad doesnt flash insight'
# 1	0.00	b'moviego would automat bypass hiphop documentari give scratch second look'
# 0	1.00	b'innocu enough make even jeanclaud van damm look good'
# 1	0.00	b'writerdirector walter hill hypermasculin element abl inject real vital even art pulpi concept mani hand would complet forgett'
# 0	1.00	b'human natur initi succe allow go crazi ultim fail spin control'
# 0	1.00	b'amid shock curios factor film corni examin young actress tri find way'
# 0	1.00	b'total overwrought deepli bias wholli design make feel guilti ignor filmmak clearli believ greatest musician time'
# 0	1.00	b'one pussyass world even killerthril revolv around group therapi session'
# 0	1.00	b'oversex time overwrought comedydrama offer littl insight experi forti femal singl'
# 1	0.00	b'ill put way your mood melodrama narrat talk fish movi'
# 1	0.00	b'even build insan stage ballroom scene 3000 actor appear full regalia waltz art film pantheon'
# 0	1.00	b'film oldfashion occasion charm subtl boldfac'
# 0	1.00	b'fanboy brought life big screen'
# 1	0.00	b'princess sorvino glide grace male persona femal without miss beat ben kingsley truli funni play kind ghandi gone bad'
# 0	1.00	b'even feel like youv seen movi thousand time kind enjoy thank mainli belushi easygo likabl'
# 1	0.00	b'understand way speak forc enough mechan poverti transcend rather simplist filmmak'
# 1	0.00	b'ye good rememb fact even better'
# 1	0.00	b'movi wear make misti even dont want'
# 0	1.00	b'simplist fluffbal whimsi'
# 0	1.00	b'notsodivin secret yaya sisterhood hefti help refri green tomato'
# 0	1.00	b'stori touch though quit enough emot reson varieti incid sustain featur even 85 minut feel bit long'
# 1	0.00	b'know plot littl crazi held interest start finish'
# 0	1.00	b'without nonstop techno existenti overton kieslowski moral tale maelstrm anoth winter sleeper'
# 1	0.00	b'aaa action xxx blast adrenalin rate eee excit vin diesel man'
# 0	1.00	b'even diehard fan japanes anim find one challeng'
# 1	0.00	b'thought tom hank ordinari bigscreen star wait youv seen eight stori tall'
# 0	1.00	b'film sort cinemat high crime one bring militari courtroom drama low'
# 1	0.00	b'quit divert nonsens'
# 0	1.00	b'unspool like highbrow lowkey 102minut infomerci blend entrepreneuri zeal testimoni satisfi custom'
# 1	0.00	b'move quickli adroitli without fuss doesnt give time reflect inan cold war dated premis'
# 0	1.00	b'director byler may yet great movi charlott sometim half one'
# 1	0.00	b'georg clooney first directori effort present utterli ridicul shaggi dog stori one creativ energet origin comedi hit screen year'
# 1	0.00	b'depend upon reaction movi may never abl look red felt sharpi pen without disgust thrill giggl'
# 0	1.00	b'jaglom offer nonetooorigin premis everyon involv moviemak con artist liar'
# 1	0.00	b'ouv got love disney pic littl cleavag one heroin feisti principl jane'
# 1	0.00	b'downward spiral come pass auto focu bear typic junki opera'
# 1	0.00	b'confluenc kiddi entertain sophist wit symbol graphic design'
# 1	0.00	b'suffer timid pars barnsid target son tri breach gap relationship father'
# 1	0.00	b'actionadventur spacebas homag robert loui stevenson treasur island fire plasma conduit'
# 1	0.00	b'strip bibl store potenti sanctimoni make meaning kid churchwari adult'
# 0	1.00	b'freaki friday'
# 0	1.00	b'there good materi stori retail clerk want life movi often spin wheel familiar situat repetit scene'
# 1	0.00	b'courag wonder big question sincer devot risk seem slow pretenti think gambl worth promis'
# 0	1.00	b'much like easili dismiss take upscal lifestyl isnt much'
# 1	0.00	b'ray liotta jason patric best work underwritten role dont fool nobodi deserv prize'
# 1	0.00	b'ok movi someth sitcom apparatu line work humor point actor humanli engag'
# 0	1.00	b'thirdperson stori told hollywood much ordinari'
# 1	0.00	b'your look intellig movi releas pent anger enough ticket need'
# 1	0.00	b'vincent gallo right home french shocker play usual bad boy weirdo role'
# 1	0.00	b'grimli compet stolid earnest militari courtroom drama'

# %% [markdown]
# Both LR and NB are straightforward machine learning algorithms; they make calculations based on how often (or likely) a word is included in positive reviews and negative reviews and build predictions based on those frequencies. That being the case, misclassified reviews most often are those in which words that are most often found in positive reviews are used in negative reviews, and vice versa. To test this hypothesis, I created a negative review that uses positive sounding words, and ran it through both algorithms to see how it was classified.

# %%
# test on a new review
test_review_1 = 'It is amazing the way that Tarantino can take a beautiful idea and make it unpalatable and hateful'
test_review_NB = predict_review_NB(test_review_1, logprior, loglikelihood)
test_review_LR = predict_review_LR(test_review_1, freqs, theta)
print(f"Test review probability, Logistic Regression: {test_review_LR}")
print(f"Test review probability, Naive Bayes: {test_review_NB:.3f}")
# Out:
# Test review probability, Logistic Regression: [[0.68460643]]
# Test review probability, Naive Bayes: 0.990

# %% [markdown]
# In both of models, the negative review above was classified as positive (LR sigmoid value > 0.5, NB p > 0). Let's try it again with a positive review that includes words most often seen in negative reviews:

# %%
# test on a new review
test_review_2 = 'A movie with this level of grime, grit, unrestrained emotion, and toxic masculinity deserves our praise'
test_review_NB = predict_review_NB(test_review_2, logprior, loglikelihood)
test_review_LR = predict_review_LR(test_review_2, freqs, theta)
print(f"Test review probability, Logistic Regression: {test_review_LR}")
print(f"Test review probability, Naive Bayes: {test_review_NB:.3f}")
# Out:
# Test review probability, Logistic Regression: [[0.27031279]]
# Test review probability, Naive Bayes: -1.161

# %% [markdown]
# Just as above, with both models, a review that is positive, but contains negative words is misclassified as negative (LR sigmoid value < 0.5, NB p < 0).
#
# This confusion is a consequence of taking each word out of context and simply tallying frequency (LR) or probability (NB) with no regard for the neighboring words in the corpus.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# While logistic regression and Naive Bayes are excellent models to know and understand, they lack some of the nuance and holistic digestion of a text corpus that you can get more advanced models using neural networds or graph-based models.

# %% [markdown]
# That being said, Naive Bayes, which uses a probabilistic approach, handily outperformed the frequentist logistic regression model.
