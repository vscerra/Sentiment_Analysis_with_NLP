# %% [markdown]
# # Continuous Bag-Of-Words Neural Network Embedding Training Notebook
#
# This notebook loads review data, cleans and splits it, builds CBOW word embeddings, and exports sentence-level embeddings

# %%
import sys
import os
sys.path.append("../")

import torch
from torch.utils.data import DataLoader
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from utils.data_utils import load_reviews
from utils.preprocessing import (
clean_text,
tokenize_and_pad,
build_vocab,
CBOWDataset, 
CBOWModel, 
train_cbow,
get_sentence_embedding
)

# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vscerra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Load and Clean Data

# %%
pos_path = "../data/positive_reviews.txt"
neg_path = "../data/negative_reviews.txt"

reviews, labels = load_reviews(pos_path, neg_path)
cleaned_reviews = [clean_text(r) for r in reviews]

# %%
# split data into training and test sets
train_reviews, test_reviews, train_labels, test_labels = train_test_split(
    cleaned_reviews, 
    labels, 
    test_size = 0.2, 
    random_state = 42)
print(f"Train size: {len(train_reviews)}, Test size: {len(test_reviews)}")
# Out:
# Train size: 8529, Test size: 2133

# %%
# save the cleaned reviews used in Training and Tests sets
with open("../data/train_texts.txt", "w", encoding="utf-8") as f:
    for review in train_reviews:
        f.write(review + "\n")

with open("../data/test_texts.txt", "w", encoding="utf-8") as f:
    for review in test_reviews:
        f.write(review + "\n")

print("train_texts.txt and test_texts.txt saved in ../data/")
# Out:
# train_texts.txt and test_texts.txt saved in ../data/

# %% [markdown]
# ## Tokenize and Build Vocabulary
#
# Training set only

# %%
#build vocab from training reviews
vocab_to_int, int_to_vocab = build_vocab(train_reviews)

#convert reviews to integer sequences
tokenized_int_train = tokenize_and_pad(train_reviews, vocab_to_int)

# %% [markdown]
# ## Prepare training dataset for CBOW

# %%
context_size = 2 # # of words before and after target word
cbow_dataset = CBOWDataset(tokenized_int_train, context_size)
cbow_loader = DataLoader(cbow_dataset, batch_size = 128, shuffle=True)

# %% [markdown]
# ## CBOW Hyperparameter Tuning
#
# Hold out 20% of the *training* reviews for CBOW validation, then search over `context_size`, `embedding_dim`, `lr`, and `epochs` to maximize downstream validation accuracy.

# %%
# split out training and validation sets
cbow_train_rev, cbow_val_rev, cbow_train_lbl, cbow_val_lbl = train_test_split(
    train_reviews, 
    train_labels,
    test_size = 0.2, 
    random_state = 42, 
    stratify = train_labels
)

# define hyperparameter grid
param_grid = {
    "context_size": [2, 3, 4],
    "embedding_dim": [50, 100, 200],
    "lr": [1e-3, 5e-4],
    "epochs": [5, 10]
}

results = []

# grid search
for context_size in param_grid["context_size"]:
    # rebuild vocab 
    vocab_to_int, int_to_vocab = build_vocab(cbow_train_rev)
    train_seq = tokenize_and_pad(cbow_train_rev, vocab_to_int)
    val_seq = tokenize_and_pad(cbow_val_rev, vocab_to_int)

    cbow_dataset = CBOWDataset(train_seq, context_size)
    cbow_loader = DataLoader(cbow_dataset, batch_size = 128, shuffle=True)

    for embedding_dim in param_grid["embedding_dim"]:
        for lr in param_grid["lr"]:
            for epochs in param_grid["epochs"]:
                model = CBOWModel(vocab_size=len(vocab_to_int), embedding_dim=embedding_dim)
                criterion = torch.nn.CrossEntropyLoss()
                optimizer = torch.optim.Adam(model.parameters(), lr=lr)

                #train
                for ep in range(epochs):
                    total_loss = 0
                    for context, target in cbow_loader:
                        optimizer.zero_grad()
                        out = model(context)
                        loss = criterion(out, target)
                        loss.backward()
                        optimizer.step()
                        total_loss += loss.item()

                #generate embeddings
                train_emb = np.array([get_sentence_embedding(model, seq) for seq in train_seq])
                val_emb = np.array([get_sentence_embedding(model, seq) for seq in val_seq])

                # logistic reg on CBOW features
                clf = LogisticRegression(max_iter=500)
                clf.fit(train_emb, cbow_train_lbl)
                val_acc = clf.score(val_emb, cbow_val_lbl)

                results.append({
                    "context_size": context_size,
                    "embedding_dim": embedding_dim,
                    "lr": lr, 
                    "epochs": epochs,
                    "val_accuracy": val_acc
                })
#results
df_results = pd.DataFrame(results)
df_results = df_results.sort_values("val_accuracy", ascending = False).reset_index(drop=True)
df_results.head(10)
# Out:
#    context_size  embedding_dim      lr  epochs  val_accuracy
# 0             2            200  0.0005      10      0.649472
# 1             4            200  0.0010      10      0.640680
# 2             4            200  0.0010       5      0.638921
# 3             2            200  0.0010      10      0.634232
# 4             4            200  0.0005      10      0.624853
# 5             2            200  0.0010       5      0.623681
# 6             3            200  0.0005      10      0.618992
# 7             2            200  0.0005       5      0.618406
# 8             3            200  0.0005       5      0.613716
# 9             3            200  0.0010      10      0.611372

# %% [markdown]
# ## Train CBOW Model

# %%
embedding_dim = 200
model = CBOWModel(vocab_size=len(vocab_to_int), embedding_dim=embedding_dim)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0005)

# train model and record loss
epochs = 100
loss_history = []
for epoch in range(epochs):
    total_loss = 0
    for context, target in cbow_loader:
        optimizer.zero_grad()
        output = model(context)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    avg_loss = total_loss / len(cbow_loader)
    loss_history.append(avg_loss)
    if epoch % 10 == 0:
        print(f"Epoch {epoch+1} / {epochs}, Loss: {avg_loss:.4f}")
        
#save trained model
torch.save(model.state_dict(), "../model/cbow_model.pth")
# Out:
# Epoch 1 / 100, Loss: 8.3208
# Epoch 11 / 100, Loss: 3.9955
# Epoch 21 / 100, Loss: 2.6045
# Epoch 31 / 100, Loss: 1.8321
# Epoch 41 / 100, Loss: 1.3367
# Epoch 51 / 100, Loss: 1.0185
# Epoch 61 / 100, Loss: 0.8135
# Epoch 71 / 100, Loss: 0.6791
# Epoch 81 / 100, Loss: 0.5876
# Epoch 91 / 100, Loss: 0.5229

# %% [markdown]
# ## Plot Training Loss

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, epochs+1), loss_history)
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.title("CBOW Training Loss Curve")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Generate and Save Sentence Embeddings

# %%
#convert both train and test reviews to int sequences
tokenized_int_test = tokenize_and_pad(test_reviews, vocab_to_int)

#compute mean-over-words embeddings
train_embeddings = [get_sentence_embedding(model, seq) for seq in tokenized_int_train]
test_embeddings = [get_sentence_embedding(model, seq) for seq in tokenized_int_test]

# save embeddings and labels
np.savez("../data/training_embeddings.npz", 
         embeddings=np.array(train_embeddings), 
         labels=np.array(train_labels)
        )

np.savez("../data/test_embeddings.npz", 
         embeddings=np.array(test_embeddings),
         labels=np.array(test_labels)
        )

print("Saved embeddings to ../data/")
# Out:
# Saved embeddings to ../data/
